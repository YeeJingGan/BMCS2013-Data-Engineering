# %% [markdown]
# # 3.0 Data Annotation
# ## 3.1 Handling Annotated Dataset
#
# ###### Author: Gan Yee Jing, Yeap Jie Shen
# ###### Last Edited: 01/09/2024
#
# ### 3.1.1 Importing Libraries

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import lower, col, when, regexp_replace, trim

import sys
sys.path.append(r'/home/student/RDS2S3G4_CLO2_B')

from data_stores.hdfsClient import HdfsClient
from data_stores.mongodbClient import MongoDBClient
from data_stores.redisClient import RedisClient

import pickle

# %% [markdown]
# ### 3.1.2 Initialising Spark Session and HDFS Client

# %%
# create spark session
spark = SparkSession.builder.appName('handle annotated dataset').getOrCreate()

# instantiate hbase client
hdfs_client = HdfsClient(spark)
# Out:
# 24/09/01 17:38:37 WARN Utils: Your hostname, Gan. resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 24/09/01 17:38:37 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/09/01 17:38:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ### 3.1.3 Retrieving Annotated Dataset from HDFS

# %%
df = hdfs_client.read_file(file_format = 'csv', source_path = 'annotated_dataset.csv', header = True, multiline = False)

df.show()
# Out:
# +---+--------------------+--------------------+--------------------+
# |key|      cleaned_tokens|               label|              label2|
# +---+--------------------+--------------------+--------------------+
# | k0|port,five,people,...| Murder and Homicide| Murder and Homicide|
# | k1|session,court,bus...|    Money Laundering|    Money Laundering|
# | k3|former,chief,exec...|    Money Laundering|    Money Laundering|
# | k4|pekan,body,late,b...| Murder and Homicide| Murder and Homicide|
# | k5|police,uncovered,...|       Drug Offences|       Drug Offences|
# | k6|court,fixed,augus...|              Others|              Others|
# | k8|former,security,g...| Murder and Homicide| Murder and Homicide|
# | k9|federal,court,uph...| Murder and Homicide| Murder and Homicide|
# |k10|court,appeal,redu...|Sexual Harassment...|Sexual Harassment...|
# |k11|investment,consul...|    Money Laundering|    Money Laundering|
# |k12|police,eight,fore...| Murder and Homicide| Murder and Homicide|
# |k14|eighteen,foreign,...|              Others|              Others|
# |k15|two,underage,girl...|Sexual Harassment...|Sexual Harassment...|
# |k16|total,foreign,pol...|Sexual Harassment...|Sexual Harassment...|
# |k18|police,driver,fou...|      Not applicable|              Others|
# |k19|former,scrap,meta...| Murder and Homicide| Murder and Homicide|
# |k20|former,constructi...|    Money Laundering|    Money Laundering|
# |k21|unemployed,man,po...|    Robbery or Theft|    Robbery or Theft|
# |k22|disabled,man,cour...| Murder and Homicide| Murder and Homicide|
# |k23|woman,lost,millio...|         Cyber Crime|         Cyber Crime|
# +---+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### 3.1.4 Resolving Inconsistency in Annotated Dataset
# #### 3.1.4.1 Fixing Incorrect Label Values

# %%
# To check for any inconsistencies
df_temp = (
    df.select('label').union(
        df.select('label2').withColumnRenamed('label2', 'label')
    ).groupby('label')
    .count()
)
df_temp.show(df_temp.count(), truncate = False)
# Out:
# +---------------------------------------------+-----+
# |label                                        |count|
# +---------------------------------------------+-----+
# |religious Offences                           |4    |
# |Scam                                         |760  |
# |Sexual Harassment or Sexual Offences or Rape |212  |
# |not applicable                               |7    |
# |Drug Offences                                |1269 |
# |Embezzlement                                 |45   |
# |NULL                                         |9    |
# |Cyber Crime                                  |137  |
# |Cybar Crime                                  |2    |
# |Religious Offences                           |68   |
# |Physical Hurt                                |886  |
# |Smuggling                                    |72   |
# |sexual Harassment or Sexual Offences or Rape |9    |
# |Smuggling                                    |138  |
# |Money Laundering                             |343  |
# |Robbery or Theft                             |569  |
# |Firearm or Terrorism                         |359  |
# |Illegal Fishing                              |1    |
# |Not applicable                               |1683 |
# | Cyber Crime                                 |1    |
# |-                                            |8    |
# |Others                                       |3    |
# |Terrorism or Firearm                         |1    |
# |Others                                       |850  |
# |Murder and Homicide                          |1206 |
# |Money laundering                             |53   |
# |Not Applicable                               |228  |
# |Dangerous Drugs                              |1    |
# |money Laundering                             |1    |
# |Sexual Harrasment or Sexual Offences or Rape |70   |
# |Moner Laundering                             |1    |
# |physical Hurt                                |1    |
# |Robbery of Theft                             |1    |
# |Smuglging                                    |1    |
# |Firearm or Terrorsim                         |1    |
# |Sexual Harrassment or Sexual Offences or Rape|26   |
# +---------------------------------------------+-----+

# %% [markdown]
# __Rename the following labels__:
# 1) 'Cybar Crime' to 'Cyber Crime'
# 2) 'Illegal Fishing' to 'Others'
# 3) '-' and 'NULL' to 'Not Applicable'
# 4) 'Terrorism or Firearm' to 'Firearm or Terrorism'
# 5) 'Dangerous Drugs' to 'Drug Offences'
# 6) 'Sexual Harrasment or Sexual Offences or Rape' and 'Sexual Harrassment or Sexual Offences or Rape' to 'Sexual Harasment or Sexual Offences or Rape'
# 7) 'Moner Laundering' to 'Money Laundering'
# 8) 'Robbery of Theft' to 'Robbery or Theft'
# 9) 'Smuglging' to 'Smuggling'
# 10) 'Firearm or Terrorsim' to 'Firearm or Terrorism'

# %%
# lower casing and remove trailing and leading spcaes
df_lc = (
    df
    .withColumn('label', regexp_replace('label', r'\s+',' '))
    .withColumn('label2', regexp_replace('label2', r'\s+',' '))
    .select('key', trim(lower('label')).alias('label'), trim(lower('label2')).alias('label2'))
)

df_lc = df_lc.withColumn(
    'label',
    when(df_lc['label'] == 'cybar crime', 'cyber crime')
    .when(df_lc['label'] == 'illegal fishing', 'others')
    .when((df_lc['label'] == '-') | (df_lc['label'].isNull()), 'not applicable')
    .when(df_lc['label'] == 'terrorism or firearm', 'firearm or terrorism')
    .when(df_lc['label'] == 'dangerous drugs', 'drug offences')
    .when(
        (df_lc['label'] == 'sexual harrasment or sexual offences or rape') | 
        (df_lc['label'] == 'sexual harrassment or sexual offences or rape'), 
        'sexual harassment or sexual offences or rape')
    .when(df_lc['label'] == 'moner laundering', 'money laundering')
    .when(df_lc['label'] == 'robbery of theft', 'robbery or theft')
    .when(df_lc['label'] == 'smuglging', 'smuggling')
    .when(df_lc['label'] == 'firearm or terrorsim', 'firearm or terrorism')
    .otherwise(df_lc['label'])
)

df_lc = df_lc.withColumn(
    'label2',
    when(df_lc['label2'] == 'cybar crime', 'cyber crime')
    .when(df_lc['label2'] == 'illegal fishing', 'others')
    .when((df_lc['label2'] == '-') | (df_lc['label2'].isNull()), 'not applicable')
    .when(df_lc['label2'] == 'terrorism or firearm', 'firearm or terrorism')
    .when(df_lc['label2'] == 'dangerous drugs', 'drug offences')
    .when(
        (df_lc['label2'] == 'sexual harrasment or sexual offences or rape') | 
        (df_lc['label2'] == 'sexual harrassment or sexual offences or rape'), 
        'sexual harassment or sexual offences or rape')
    .when(df_lc['label2'] == 'moner laundering', 'money laundering')
    .when(df_lc['label2'] == 'robbery of theft', 'robbery or theft')
    .when(df_lc['label2'] == 'smuglging', 'smuggling')
    .when(df_lc['label2'] == 'firearm or terrorsim', 'firearm or terrorism')
    .otherwise(df_lc['label2'])
)

# To check for any inconsistencies
df_temp = (
    df_lc.select('label').union(
        df_lc.select('label2').withColumnRenamed('label2', 'label')
    ).groupby('label')
    .count()
)
df_temp.show(df_temp.count(), truncate = False)
# Out:
# +--------------------------------------------+-----+
# |label                                       |count|
# +--------------------------------------------+-----+
# |drug offences                               |1270 |
# |not applicable                              |1935 |
# |cyber crime                                 |140  |
# |scam                                        |760  |
# |smuggling                                   |211  |
# |others                                      |854  |
# |sexual harassment or sexual offences or rape|317  |
# |murder and homicide                         |1206 |
# |physical hurt                               |887  |
# |firearm or terrorism                        |361  |
# |money laundering                            |398  |
# |religious offences                          |72   |
# |embezzlement                                |45   |
# |robbery or theft                            |570  |
# +--------------------------------------------+-----+

# %% [markdown]
# #### 3.1.4.2 Indicating Mismatch Labels

# %%
# Compare label and label2
df_lc = df_lc.withColumn('equal', df_lc.label == df_lc.label2)

# Generate category column (if equal is True, category = label, else = not applicable)
df_category = df_lc.withColumn(
    'category',
    when(col('equal') == True, col('label'))
    .when(col('equal') == False, 'not applicable')
)

df_category.show()
# Out:
# +---+--------------------+--------------------+-----+--------------------+
# |key|               label|              label2|equal|            category|
# +---+--------------------+--------------------+-----+--------------------+
# | k0| murder and homicide| murder and homicide| true| murder and homicide|
# | k1|    money laundering|    money laundering| true|    money laundering|
# | k3|    money laundering|    money laundering| true|    money laundering|
# | k4| murder and homicide| murder and homicide| true| murder and homicide|
# | k5|       drug offences|       drug offences| true|       drug offences|
# | k6|              others|              others| true|              others|
# | k8| murder and homicide| murder and homicide| true| murder and homicide|
# | k9| murder and homicide| murder and homicide| true| murder and homicide|
# |k10|sexual harassment...|sexual harassment...| true|sexual harassment...|
# |k11|    money laundering|    money laundering| true|    money laundering|
# |k12| murder and homicide| murder and homicide| true| murder and homicide|
# |k14|              others|              others| true|              others|
# |k15|sexual harassment...|sexual harassment...| true|sexual harassment...|
# |k16|sexual harassment...|sexual harassment...| true|sexual harassment...|
# |k18|      not applicable|              others|false|      not applicable|
# |k19| murder and homicide| murder and homicide| true| murder and homicide|
# |k20|    money laundering|    money laundering| true|    money laundering|
# |k21|    robbery or theft|    robbery or theft| true|    robbery or theft|
# |k22| murder and homicide| murder and homicide| true| murder and homicide|
# |k23|         cyber crime|         cyber crime| true|         cyber crime|
# +---+--------------------+--------------------+-----+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### 3.1.5 Retrieving Cleaned Dataset from MongoDB

# %%
mongodb_client = MongoDBClient()
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# read data from mongoDB, exclude id generated by MongoDB
cursor = mongodb_client.read_many('Cleaned_Dataset', 'cleaned_data', {'_id': False}) # exclude id objects

# convert cursor to list of dictionaries
data_list = list(cursor)

# convert list of dictionaries to dataframe
df_cleaned = spark.createDataFrame(data_list)

df_cleaned.show()
# Out:
# +------+--------------------+---+----------------+--------------------+--------------------+--------------------+
# |author|            datetime|key|       publisher|   tokenised_content|  tokenised_headline|                 url|
# +------+--------------------+---+----------------+--------------------+--------------------+--------------------+
# |      |2024-07-19T20:15:...| k0|Selangor Journal|[port, five, peop...|[five, causing, d...|https://selangorj...|
# |      |2024-07-19T17:30:...| k1|Selangor Journal|[session, court, ...|[businessman, che...|https://selangorj...|
# |      |2024-07-18T21:12:...| k3|Selangor Journal|[former, chief, e...|[year, jail, fine...|https://selangorj...|
# |      |2024-07-18T19:58:...| k4|Selangor Journal|[pekan, body, lat...|[remains, laid, r...|https://selangorj...|
# |      |2024-07-18T19:45:...| k5|Selangor Journal|[police, uncovere...|[police, seize, c...|https://selangorj...|
# |      |2024-07-18T17:09:...| k6|Selangor Journal|[court, fixed, au...| [guilty, therapist]|https://selangorj...|
# |      |2024-07-17T23:11:...| k8|Selangor Journal|[former, security...|[murder, guard, e...|https://selangorj...|
# |      |2024-07-16T21:09:...| k9|Selangor Journal|[federal, court, ...|[federal, court, ...|https://selangorj...|
# |      |2024-07-16T19:12:...|k10|Selangor Journal|[court, appeal, r...|[father, sexually...|https://selangorj...|
# |      |2024-07-16T17:08:...|k11|Selangor Journal|[investment, cons...|[consultant, nearly]|https://selangorj...|
# |      |2024-07-14T14:40:...|k12|Selangor Journal|[police, eight, f...|[arrest, eight, d...|https://selangorj...|
# |      |2024-07-12T16:07:...|k14|Selangor Journal|[eighteen, foreig...| [involvement, scam]|https://selangorj...|
# |      |2024-07-12T13:58:...|k15|Selangor Journal|[underage, girl, ...|          [underage]|https://selangorj...|
# |      |2024-07-07T16:34:...|k16|Selangor Journal|[total, foreign, ...|[police, detain, ...|https://selangorj...|
# |      |2024-07-04T22:58:...|k18|Selangor Journal|[police, driver, ...|[lookout, driver,...|https://selangorj...|
# |      |2024-07-04T19:05:...|k19|Selangor Journal|[former, scrap, m...|[death, sentence,...|https://selangorj...|
# |      |2024-07-03T23:08:...|k20|Selangor Journal|[former, construc...|[former, company,...|https://selangorj...|
# |      |2024-07-03T19:18:...|k21|Selangor Journal|[unemployed, poli...|[unemployed, robb...|https://selangorj...|
# |      |2024-07-03T19:13:...|k22|Selangor Journal|[disabled, court,...|[disabled, matric...|https://selangorj...|
# |      |2024-07-03T19:12:...|k23|Selangor Journal|[woman, lost, mil...|[woman, investmen...|https://selangorj...|
# +------+--------------------+---+----------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### 3.1.6 Joining Annotated Column to Cleaned Dataset

# %%
df_annotated = (
    df_cleaned
    .join(df_category, df_cleaned.key == df_category.key)
    .select(df_cleaned.key, 
            df_cleaned.tokenised_content, 
            df_cleaned.tokenised_headline, 
            df_cleaned.author, 
            df_cleaned.datetime, 
            df_cleaned.publisher, 
            df_cleaned.url, 
            df_category.category)
)
df_annotated.show()
# Out:
# +---+--------------------+--------------------+------+--------------------+----------------+--------------------+--------------------+
# |key|   tokenised_content|  tokenised_headline|author|            datetime|       publisher|                 url|            category|
# +---+--------------------+--------------------+------+--------------------+----------------+--------------------+--------------------+
# | k0|[port, five, peop...|[five, causing, d...|      |2024-07-19T20:15:...|Selangor Journal|https://selangorj...| murder and homicide|
# | k1|[session, court, ...|[businessman, che...|      |2024-07-19T17:30:...|Selangor Journal|https://selangorj...|    money laundering|
# | k3|[former, chief, e...|[year, jail, fine...|      |2024-07-18T21:12:...|Selangor Journal|https://selangorj...|    money laundering|
# | k4|[pekan, body, lat...|[remains, laid, r...|      |2024-07-18T19:58:...|Selangor Journal|https://selangorj...| murder and homicide|
# | k5|[police, uncovere...|[police, seize, c...|      |2024-07-18T19:45:...|Selangor Journal|https://selangorj...|       drug offences|
# | k6|[court, fixed, au...| [guilty, therapist]|      |2024-07-18T17:09:...|Selangor Journal|https://selangorj...|              others|
# | k8|[former, security...|[murder, guard, e...|      |2024-07-17T23:11:...|Selangor Journal|https://selangorj...| murder and homicide|
# | k9|[federal, court, ...|[federal, court, ...|      |2024-07-16T21:09:...|Selangor Journal|https://selangorj...| murder and homicide|
# |k10|[court, appeal, r...|[father, sexually...|      |2024-07-16T19:12:...|Selangor Journal|https://selangorj...|sexual harassment...|
# |k11|[investment, cons...|[consultant, nearly]|      |2024-07-16T17:08:...|Selangor Journal|https://selangorj...|    money laundering|
# |k12|[police, eight, f...|[arrest, eight, d...|      |2024-07-14T14:40:...|Selangor Journal|https://selangorj...| murder and homicide|
# |k14|[eighteen, foreig...| [involvement, scam]|      |2024-07-12T16:07:...|Selangor Journal|https://selangorj...|              others|
# |k15|[underage, girl, ...|          [underage]|      |2024-07-12T13:58:...|Selangor Journal|https://selangorj...|sexual harassment...|
# |k16|[total, foreign, ...|[police, detain, ...|      |2024-07-07T16:34:...|Selangor Journal|https://selangorj...|sexual harassment...|
# |k18|[police, driver, ...|[lookout, driver,...|      |2024-07-04T22:58:...|Selangor Journal|https://selangorj...|      not applicable|
# |k19|[former, scrap, m...|[death, sentence,...|      |2024-07-04T19:05:...|Selangor Journal|https://selangorj...| murder and homicide|
# |k20|[former, construc...|[former, company,...|      |2024-07-03T23:08:...|Selangor Journal|https://selangorj...|    money laundering|
# |k21|[unemployed, poli...|[unemployed, robb...|      |2024-07-03T19:18:...|Selangor Journal|https://selangorj...|    robbery or theft|
# |k22|[disabled, court,...|[disabled, matric...|      |2024-07-03T19:13:...|Selangor Journal|https://selangorj...| murder and homicide|
# |k23|[woman, lost, mil...|[woman, investmen...|      |2024-07-03T19:12:...|Selangor Journal|https://selangorj...|         cyber crime|
# +---+--------------------+--------------------+------+--------------------+----------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### 3.1.7 Dropping Not Applicable Data

# %%
df_annotated = df_annotated.filter(df_annotated['category'] != 'not applicable')
df_annotated.show()
# Out:
# +---+--------------------+--------------------+------+--------------------+----------------+--------------------+--------------------+
# |key|   tokenised_content|  tokenised_headline|author|            datetime|       publisher|                 url|            category|
# +---+--------------------+--------------------+------+--------------------+----------------+--------------------+--------------------+
# | k0|[port, five, peop...|[five, causing, d...|      |2024-07-19T20:15:...|Selangor Journal|https://selangorj...| murder and homicide|
# | k1|[session, court, ...|[businessman, che...|      |2024-07-19T17:30:...|Selangor Journal|https://selangorj...|    money laundering|
# | k3|[former, chief, e...|[year, jail, fine...|      |2024-07-18T21:12:...|Selangor Journal|https://selangorj...|    money laundering|
# | k4|[pekan, body, lat...|[remains, laid, r...|      |2024-07-18T19:58:...|Selangor Journal|https://selangorj...| murder and homicide|
# | k5|[police, uncovere...|[police, seize, c...|      |2024-07-18T19:45:...|Selangor Journal|https://selangorj...|       drug offences|
# | k6|[court, fixed, au...| [guilty, therapist]|      |2024-07-18T17:09:...|Selangor Journal|https://selangorj...|              others|
# | k8|[former, security...|[murder, guard, e...|      |2024-07-17T23:11:...|Selangor Journal|https://selangorj...| murder and homicide|
# | k9|[federal, court, ...|[federal, court, ...|      |2024-07-16T21:09:...|Selangor Journal|https://selangorj...| murder and homicide|
# |k10|[court, appeal, r...|[father, sexually...|      |2024-07-16T19:12:...|Selangor Journal|https://selangorj...|sexual harassment...|
# |k11|[investment, cons...|[consultant, nearly]|      |2024-07-16T17:08:...|Selangor Journal|https://selangorj...|    money laundering|
# |k12|[police, eight, f...|[arrest, eight, d...|      |2024-07-14T14:40:...|Selangor Journal|https://selangorj...| murder and homicide|
# |k14|[eighteen, foreig...| [involvement, scam]|      |2024-07-12T16:07:...|Selangor Journal|https://selangorj...|              others|
# |k15|[underage, girl, ...|          [underage]|      |2024-07-12T13:58:...|Selangor Journal|https://selangorj...|sexual harassment...|
# |k16|[total, foreign, ...|[police, detain, ...|      |2024-07-07T16:34:...|Selangor Journal|https://selangorj...|sexual harassment...|
# |k19|[former, scrap, m...|[death, sentence,...|      |2024-07-04T19:05:...|Selangor Journal|https://selangorj...| murder and homicide|
# |k20|[former, construc...|[former, company,...|      |2024-07-03T23:08:...|Selangor Journal|https://selangorj...|    money laundering|
# |k21|[unemployed, poli...|[unemployed, robb...|      |2024-07-03T19:18:...|Selangor Journal|https://selangorj...|    robbery or theft|
# |k22|[disabled, court,...|[disabled, matric...|      |2024-07-03T19:13:...|Selangor Journal|https://selangorj...| murder and homicide|
# |k23|[woman, lost, mil...|[woman, investmen...|      |2024-07-03T19:12:...|Selangor Journal|https://selangorj...|         cyber crime|
# |k24|[high, court, for...|[legal, serve, se...|      |2024-07-03T12:18:...|Selangor Journal|https://selangorj...|              others|
# +---+--------------------+--------------------+------+--------------------+----------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# check remaining row number
df_annotated.count()
# Out:
# 2591

# %%
# check number of rows for each categories
df_annotated.groupBy('category').count().show(truncate = False)
# Out:
# +--------------------------------------------+-----+
# |category                                    |count|
# +--------------------------------------------+-----+
# |drug offences                               |566  |
# |cyber crime                                 |20   |
# |scam                                        |360  |
# |others                                      |154  |
# |sexual harassment or sexual offences or rape|127  |
# |murder and homicide                         |500  |
# |physical hurt                               |313  |
# |firearm or terrorism                        |128  |
# |money laundering                            |114  |
# |religious offences                          |20   |
# |robbery or theft                            |229  |
# |smuggling                                   |48   |
# |embezzlement                                |12   |
# +--------------------------------------------+-----+

# %% [markdown]
# __Findings__: We consider to merge categories that having small sample size. Hence,
# 1) 'embezzlement' and 'smuggling' are merged into 'money laundering'
# 2) 'religious offences' is merged into 'others'
# 3) 'cyber crime' is merged into 'scam'

# %% [markdown]
# ### 3.1.8 Merging Categories

# %%
df_merged = df_annotated.withColumn(
    'category',
    when((df_annotated['category'] == 'embezzlement') | (df_annotated['category'] == 'smuggling'), 'money laundering')
    .when(df_annotated['category'] == 'religious offences', 'others')
    .when(df_annotated['category'] == 'cyber crime', 'scam')
    .otherwise(df_annotated['category'])
)

df_merged.groupBy('category').count().show(truncate = False)
# Out:
# +--------------------------------------------+-----+
# |category                                    |count|
# +--------------------------------------------+-----+
# |drug offences                               |566  |
# |scam                                        |380  |
# |others                                      |174  |
# |sexual harassment or sexual offences or rape|127  |
# |murder and homicide                         |500  |
# |physical hurt                               |313  |
# |firearm or terrorism                        |128  |
# |money laundering                            |174  |
# |robbery or theft                            |229  |
# +--------------------------------------------+-----+

# %% [markdown]
# ### 3.1.9 Storing Annotated Dataset to MongoDB and Redis (for caching)

# %%
redis_client = RedisClient(host = 'localhost', port = 6379, db = 0, start_now = True)
# Out:
# [sudo] password for student:

# %%
# Convert dataframe into list of dictionaries to efficiently insert data into MongoDB
documents = df_merged.rdd.map(lambda row: {
    'key': row[0], 
    'tokenised_content': row[1], 
    'tokenised_headline': row[2], 
    'author': row[3],
    'datetime': row[4],
    'publisher': row[5],
    'url': row[6],
    'category': row[7]}
).collect()

# %%
redis_client.set_key_value('annotated_dataset', pickle.dumps(documents), seconds = 30 * 60)
# Out:
# True

# %%
mongodb_client.insert_many('Annotated_Dataset', 'annotated_data', documents)
# Out:
# Documents successfully inserted: [ObjectId('66d43635f047a97f234a6255'), ObjectId('66d43635f047a97f234a6256'), ObjectId('66d43635f047a97f234a6257'), ObjectId('66d43635f047a97f234a6258'), ObjectId('66d43635f047a97f234a6259'), ObjectId('66d43635f047a97f234a625a'), ObjectId('66d43635f047a97f234a625b'), ObjectId('66d43635f047a97f234a625c'), ObjectId('66d43635f047a97f234a625d'), ObjectId('66d43635f047a97f234a625e'), ObjectId('66d43635f047a97f234a625f'), ObjectId('66d43635f047a97f234a6260'), ObjectId('66d43635f047a97f234a6261'), ObjectId('66d43635f047a97f234a6262'), ObjectId('66d43635f047a97f234a6263'), ObjectId('66d43635f047a97f234a6264'), ObjectId('66d43635f047a97f234a6265'), ObjectId('66d43635f047a97f234a6266'), ObjectId('66d43635f047a97f234a6267'), ObjectId('66d43635f047a97f234a6268'), ObjectId('66d43635f047a97f234a6269'), ObjectId('66d43635f047a97f234a626a'), ObjectId('66d43635f047a97f234a626b'), ObjectId('66d43635f047a97f234a626c'), ObjectId('66d43635f047a97f234a626d'), ObjectId('66d43635f047a97f234a626e'), ObjectId('66d43635f047a97f234a626f'), ObjectId('66d43635f047a97f234a6270'), ObjectId('66d43635f047a97f234a6271'), ObjectId('66d43635f047a97f234a6272'), ObjectId('66d43635f047a97f234a6273'), ObjectId('66d43635f047a97f234a6274'), ObjectId('66d43635f047a97f234a6275'), ObjectId('66d43635f047a97f234a6276'), ObjectId('66d43635f047a97f234a6277'), ObjectId('66d43635f047a97f234a6278'), ObjectId('66d43635f047a97f234a6279'), ObjectId('66d43635f047a97f234a627a'), ObjectId('66d43635f047a97f234a627b'), ObjectId('66d43635f047a97f234a627c'), ObjectId('66d43635f047a97f234a627d'), ObjectId('66d43635f047a97f234a627e'), ObjectId('66d43635f047a97f234a627f'), ObjectId('66d43635f047a97f234a6280'), ObjectId('66d43635f047a97f234a6281'), ObjectId('66d43635f047a97f234a6282'), ObjectId('66d43635f047a97f234a6283'), ObjectId('66d43635f047a97f234a6284'), ObjectId('66d43635f047a97f234a6285'), ObjectId('66d43635f047a97f234a6286'), ObjectId('66d43635f047a97f234a6287'), ObjectId('66d43635f047a97f234a6288'), ObjectId('66d43635f047a97f234a6289'), ObjectId('66d43635f047a97f234a628a'), ObjectId('66d43635f047a97f234a628b'), ObjectId('66d43635f047a97f234a628c'), ObjectId('66d43635f047a97f234a628d'), ObjectId('66d43635f047a97f234a628e'), ObjectId('66d43635f047a97f234a628f'), ObjectId('66d43635f047a97f234a6290'), ObjectId('66d43635f047a97f234a6291'), ObjectId('66d43635f047a97f234a6292'), ObjectId('66d43635f047a97f234a6293'), ObjectId('66d43635f047a97f234a6294'), ObjectId('66d43635f047a97f234a6295'), ObjectId('66d43635f047a97f234a6296'), ObjectId('66d43635f047a97f234a6297'), ObjectId('66d43635f047a97f234a6298'), ObjectId('66d43635f047a97f234a6299'), ObjectId('66d43635f047a97f234a629a'), ObjectId('66d43635f047a97f234a629b'), ObjectId('66d43635f047a97f234a629c'), ObjectId('66d43635f047a97f234a629d'), ObjectId('66d43635f047a97f234a629e'), ObjectId('66d43635f047a97f234a629f'), ObjectId('66d43635f047a97f234a62a0'), ObjectId('66d43635f047a97f234a62a1'), ObjectId('66d43635f047a97f234a62a2'), ObjectId('66d43635f047a97f234a62a3'), ObjectId('66d43635f047a97f234a62a4'), ObjectId('66d43635f047a97f234a62a5'), ObjectId('66d43635f047a97f234a62a6'), ObjectId('66d43635f047a97f234a62a7'), ObjectId('66d43635f047a97f234a62a8'), ObjectId('66d43635f047a97f234a62a9'), ObjectId('66d43635f047a97f234a62aa'), ObjectId('66d43635f047a97f234a62ab'), ObjectId('66d43635f047a97f234a62ac'), ObjectId('66d43635f047a97f234a62ad'), ObjectId('66d43635f047a97f234a62ae'), ObjectId('66d43635f047a97f234a62af'), ObjectId('66d43635f047a97f234a62b0'), ObjectId('66d43635f047a97f234a62b1'), ObjectId('66d43635f047a97f234a62b2'), ObjectId('66d43635f047a97f234a62b3'), ObjectId('66d43635f047a97f234a62b4'), ObjectId('66d43635f047a97f234a62b5'), ObjectId('66d43635f047a97f234a62b6'), ObjectId('66d43635f047a97f234a62b7'), ObjectId('66d43635f047a97f234a62b8'), ObjectId('66d43635f047a97f234a62b9'), ObjectId('66d43635f047a97f234a62ba'), ObjectId('66d43635f047a97f234a62bb'), ObjectId('66d43635f047a97f234a62bc'), ObjectId('66d4 ...

# %%
pickle.loads(redis_client.get_value('annotated_dataset'))
# Out:
# [{'key': 'k0',
#   'tokenised_content': ['port',
#    'five',
#    'people',
#    'court',
#    'today',
#    'causing',
#    'death',
#    'friend',
#    'swimming',
#    'pool',
#    'last',
#    'week',
#    'accused',
#    'guilty',
#    'charge',
#    'read',
#    'magistrate',
#    'jointly',
#    'accused',
#    'causing',
#    'death',
#    'hotel',
#    'swimming',
#    'pool',
#    'port',
#    'charge',
#    'section',
#    'penal',
#    'code',
#    'read',
#    'together',
#    'section',
#    'maximum',
#    'jail',
#    'term',
#    'fine',
#    'upon',
#    'conviction',
#    'deputy',
#    'public',
#    'prosecutor',
#    'bail',
#    'accused',
#    'court',
#    'impose',
#    'additional',
#    'condition',
#    'disturb',
#    'prosecution',
#    'case',
#    'resolved',
#    'court',
#    'accused',
#    'bail',
#    'surety',
#    'lawyer',
#    'court',
#    'five',
#    'accused',
#    'guilty',
#    'second',
#    'charge',
#    'allegedly',
#    'port',
#    'police',
#    'headquarters',
#    'court',
#    'bail',
#    'fixed',
#    'mention'],
#   'tokenised_headline': ['five',
#    'causing',
#    'death',
#    'hotel',
#    'swimming',
#    'pool'],
#   'author': '',
#   'datetime': '2024-07-19T20:15:23+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/five-charged-with-causing-friends-death-in-hotel-swimming-pool/',
#   'category': 'murder and homicide'},
#  {'key': 'k1',
#   'tokenised_content': ['session',
#    'court',
#    'businessman',
#    'three',
#    'allegedly',
#    'deceiving',
#    'acquaintance',
#    'payment',
#    'overdue',
#    'inland',
#    'revenue',
#    'board',
#    'judge',
#    'found',
#    'defence',
#    'successfully',
#    'raised',
#    'reasonable',
#    'doubt',
#    'case',
#    'therefore',
#    'accused',
#    'three',
#    'said',
#    'accused',
#    'deceiving',
#    'tricking',
#    'settling',
#    'overdue',
#    'transfer',
#    'million',
#    'bank',
#    'account',
#    'accused',
#    'section',
#    'penal',
#    'code',
#    'imprisonment',
#    'include',
#    'fine',
#    'upon',
#    'conviction',
#    'four',
#    'prosecution',
#    'defence',
#    'witness',
#    'namely',
#    'accused',
#    'trial',
#    'deputy',
#    'public',
#    'prosecutor',
#    'handled',
#    'prosecution',
#    'accused',
#    'lawyer'],
#   'tokenised_headline': ['businessman', 'cheating'],
#   'author': '',
#   'datetime': '2024-07-19T17:30:19+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/businessman-acquitted-of-cheating-charges-involving-irb-tax-arrears/',
#   'category': 'money laundering'},
#  {'key': 'k3',
#   'tokenised_content': ['former',
#    'chief',
#    'executive',
#    'officer',
#    'automotive',
#    'institute',
#    'year',
#    'prison',
#    'session',
#    'today',
#    'fraudulently',
#    'million',
#    'automotive',
#    'training',
#    'contract',
#    'million',
#    'cash',
#    'ordered',
#    'prison',
#    'automotive',
#    'institute',
#    'former',
#    'concurrently',
#    'today',
#    'first',
#    'instance',
#    'judge',
#    'year',
#    'prison',
#    'guilty',
#    'alternative',
#    'charge',
#    'deceiving',
#    'board',
#    'believing',
#    'learning',
#    'contract',
#    'price',
#    'million',
#    'actually',
#    'million',
#    'board',
#    'award',
#    'company',
#    'million',
#    'contract',
#    'training',
#    'provider',
#    'central',
#    'east',
#    'coast',
#    'southern',
#    'also',
#    'ordered',
#    'accused',
#    'serve',
#    'additional',
#    'prison',
#    'term',
#    'accused',
#    'settle',
#    'fine',
#    'hotel',
#    'along',
#    'section',
#    'penal',
#    'code',
#    'imprisonment',
#    'fine',
#    'upon',
#    'conviction',
#    'judge',
#    'year',
#    'prison',
#    'ordered',
#    'confiscation',
#    'asset',
#    'worth',
#    'million',
#    'guilty',
#    'another',
#    'alternative',
#    'charge',
#    'million',
#    'cash',
#    'bank',
#    'section',
#    'shah',
#    'accused',
#    'section',
#    'penal',
#    'code',
#    'maximum',
#    'imprisonment',
#    'fine',
#    'upon',
#    'conviction',
#    'however',
#    'initial',
#    'main',
#    'section',
#    'section',
#    'penal',
#    'code',
#    'section',
#    'commission',
#    'section',
#    'proceeds',
#    'unlawful',
#    'taken',
#    'consideration',
#    'section',
#    'criminal',
#    'procedure',
#    'code',
#    'deputy',
#    'public',
#    'chin',
#    'alias',
#    'handled',
#    'prosecution',
#    'accused'],
#   'tokenised_headline': ['year', 'jail', 'fine', 'deceiving', 'board'],
#   'author': '',
#   'datetime': '2024-07-18T21:12:41+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/ex-marii-ceo-gets-one-year-jail-fine-for-deceiving-board-of-directors/',
#   'category': 'money laundering'},
#  {'key': 'k4',
#   'tokenised_content': ['pekan',
#    'body',
#    'late',
#    'buried',
#    'cemetery',
#    'today',
#    'carrying',
#    'former',
#    'sultan',
#    'student',
#    'cemetery',
#    'brought',
#    'forensic',
#    'department',
#    'funeral',
#    'murder',
#    'victim',
#    'family',
#    'state',
#    'investment',
#    'industry',
#    'science',
#    'technology',
#    'innovation',
#    'committee',
#    'chairman',
#    'state',
#    'government',
#    'also',
#    'present',
#    'ceremony',
#    'remains',
#    'found',
#    'palm',
#    'plantation',
#    'hulu',
#    'missing',
#    'since',
#    'last',
#    'rental',
#    'customer',
#    'following',
#    'police',
#    'officer',
#    'assist',
#    'investigation',
#    'related',
#    'case',
#    'section',
#    'penal',
#    'code'],
#   'tokenised_headline': ['remains', 'laid', 'rest', 'pekan'],
#   'author': '',
#   'datetime': '2024-07-18T19:58:15+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/nur-farah-kartinis-remains-laid-to-rest-in-pekan/',
#   'category': 'murder and homicide'},
#  {'key': 'k5',
#   'tokenised_content': ['police',
#    'uncovered',
#    'cocaine',
#    'laboratory',
#    'three',
#    'wife',
#    'police',
#    'also',
#    'cocaine',
#    'worth',
#    'million',
#    'crime',
#    'investigation',
#    'department',
#    'collaboration',
#    'united',
#    'drug',
#    'enforcement',
#    'administration',
#    'director',
#    'chin',
#    'said',
#    'operation',
#    'wife',
#    'aged',
#    'condominium',
#    'unit',
#    'along',
#    'upon',
#    'searching',
#    'unit',
#    'police',
#    'found',
#    'cocaine',
#    'kept',
#    'preliminary',
#    'found',
#    'runner',
#    'wife',
#    'supply',
#    'said',
#    'press',
#    'conference',
#    'police',
#    'headquarters',
#    'today',
#    'preliminary',
#    'also',
#    'found',
#    'couple',
#    'rented',
#    'unit',
#    'used',
#    'store',
#    'cocaine',
#    'laboratory',
#    'since',
#    'month',
#    'following',
#    'arrest',
#    'said',
#    'police',
#    'also',
#    'acting',
#    'runner',
#    'syndicate',
#    'apartment',
#    'chemical',
#    'powder',
#    'unit',
#    'added',
#    'preliminary',
#    'found',
#    'syndicate',
#    'active',
#    'since',
#    'early',
#    'year',
#    'used',
#    'place',
#    'process',
#    'store',
#    'cocaine',
#    'distributed',
#    'overseas',
#    'transport',
#    'tested',
#    'positive',
#    'eight',
#    'prior',
#    'criminal',
#    'drug',
#    'wife',
#    'seven',
#    'four',
#    'said',
#    'case',
#    'section',
#    'dangerous'],
#   'tokenised_headline': ['police', 'seize', 'cocaine', 'raid'],
#   'author': '',
#   'datetime': '2024-07-18T19:45:02+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/police-seize-rm9-mln-in-drugs-after-cocaine-lab-raid/',
#   'category': 'drug offences'},
#  {'key': 'k6',
#   'tokenised_content': ['court',
#    'fixed',
#    'august',
#    'guilty',
#    'charge',
#    'woman',
#    'intent',
#    'outrage',
#    'modesty',
#    'made',
#    'plea',
#    'charge',
#    'read',
#    'court',
#    'interpreter',
#    'magistrate',
#    'bail',
#    'local',
#    'magistrate',
#    'also',
#    'ordered',
#    'surrender',
#    'passport',
#    'court',
#    'report',
#    'nearest',
#    'police',
#    'station',
#    'pending',
#    'disposal',
#    'case',
#    'criminal',
#    'force',
#    'woman',
#    'therapist',
#    'outrage',
#    'modesty',
#    'island',
#    'section',
#    'penal',
#    'code',
#    'imprisonment',
#    'fine',
#    'whipping',
#    'upon',
#    'conviction',
#    'deputy',
#    'public',
#    'prosecutor',
#    'prosecution',
#    'lawyer'],
#   'tokenised_headline': ['guilty', 'therapist'],
#   'author': '',
#   'datetime': '2024-07-18T17:09:18+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/moroccan-pleads-guilty-to-assaulting-therapist-at-spa/',
#   'category': 'others'},
#  {'key': 'k8',
#   'tokenised_content': ['former',
#    'security',
#    'guard',
#    'death',
#    'penalty',
#    'federal',
#    'court',
#    'year',
#    'prison',
#    'sentence',
#    'murdering',
#    'teenage',
#    'daughter',
#    'panel',
#    'chief',
#    'justice',
#    'tuan',
#    'handed',
#    'prison',
#    'sentence',
#    'application',
#    'review',
#    'death',
#    'sentence',
#    'judge',
#    'along',
#    'federal',
#    'court',
#    'judge',
#    'court',
#    'appeal',
#    'judge',
#    'ordered',
#    'prison',
#    'sentence',
#    'start',
#    'date',
#    'arrest',
#    'found',
#    'guilty',
#    'murdering',
#    'palm',
#    'plantation',
#    'june',
#    'deputy',
#    'public',
#    'prosecutor',
#    'court',
#    'uphold',
#    'death',
#    'penalty',
#    'victim',
#    'still',
#    'child',
#    'time',
#    'brutally',
#    'beaten',
#    'neck',
#    'burned',
#    'however',
#    'lawyer',
#    'review',
#    'application',
#    'death',
#    'high',
#    'court',
#    'appeal',
#    'court',
#    'appeal',
#    'march',
#    'federal',
#    'court',
#    'sitting',
#    'august',
#    'also',
#    'upheld',
#    'death',
#    'sentence',
#    'meanwhile',
#    'court',
#    'also',
#    'aside',
#    'death',
#    'penalty',
#    'found',
#    'guilty',
#    'murdering',
#    'stabbing',
#    'time',
#    'pouring',
#    'formic',
#    'acid',
#    'head',
#    'hospital',
#    'later',
#    'court',
#    'death',
#    'penalty',
#    'year',
#    'prison',
#    'sentence',
#    'starting',
#    'date',
#    'arrest',
#    'court',
#    'maintain',
#    'death',
#    'sentence',
#    'victim',
#    'pregnant',
#    'time',
#    'incident',
#    'meant',
#    'took',
#    'lawyer',
#    'said',
#    'client',
#    'admitted',
#    'police',
#    'station',
#    'family',
#    'incident',
#    'prison',
#    'session',
#    'court',
#    'pleading',
#    'guilty',
#    'murder',
#    'knife',
#    'addition',
#    'another',
#    'year',
#    'prison',
#    'sentence',
#    'splashing',
#    'formic',
#    'acid',
#    'seriously',
#    'victim',
#    'baru',
#    'redan',
#    'court',
#    'appeal',
#    'charge',
#    'section',
#    'penal',
#    'code',
#    'murder',
#    'resulting',
#    'death',
#    'penalty',
#    'upheld',
#    'federal',
#    'court',
#    'march',
#    'meanwhile',
#    'former',
#    'police',
#    'corporal',
#    'also',
#    'death',
#    'penalty',
#    'prison',
#    'murdering',
#    'pregnant',
#    'court',
#    'ordered',
#    'serve',
#    'sentence',
#    'starting',
#    'date',
#    'arrest',
#    'murdering',
#    'woman',
#    'bandar',
#    'death',
#    'penalty',
#    'upheld',
#    'autopsy',
#    'report',
#    'revealed',
#    'cause',
#    'death',
#    'severe',
#    'blow',
#    'blunt',
#    'object',
#    'head',
#    'deceased',
#    'also',
#    'body',
#    'baby',
#    'womb',
#    'also',
#    'applicant',
#    'also',
#    'victim',
#    'pleading',
#    'beaten',
#    'applicant',
#    'said',
#    'lawyer',
#    'shah',
#    'said',
#    'client',
#    'intended',
#    'take',
#    'victim',
#    'medical',
#    'treatment',
#    'court',
#    'appeal',
#    'upheld',
#    'conviction',
#    'death',
#    'sentence',
#    'federal',
#    'court',
#    'also',
#    'decision'],
#   'tokenised_headline': ['murder',
#    'guard',
#    'escape',
#    'gallows',
#    'federal',
#    'court',
#    'review'],
#   'author': '',
#   'datetime': '2024-07-17T23:11:48+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/murder-ex-security-guard-ex-policeman-escape-gallows-after-federal-court-review/',
#   'category': 'murder and homicide'},
#  {'key': 'k9',
#   'tokenised_content': ['federal',
#    'court',
#    'upheld',
#    'death',
#    'sentence',
#    'stepson',
#    'panel',
#    'chief',
#    'justice',
#    'tuan',
#    'made',
#    'unanimous',
#    'decision',
#    'reject',
#    'application',
#    'review',
#    'death',
#    'sentence',
#    'life',
#    'imprisonment',
#    'accordance',
#    'sentence',
#    'death',
#    'imprisonment',
#    'natural',
#    'life',
#    'temporary',
#    'jurisdiction',
#    'federal',
#    'court',
#    'accepted',
#    'objection',
#    'review',
#    'application',
#    'aside',
#    'death',
#    'sentence',
#    'application',
#    'accused',
#    'hereby',
#    'sentence',
#    'upheld',
#    'said',
#    'federal',
#    'court',
#    'attorney',
#    'division',
#    'head',
#    'review',
#    'application',
#    'court',
#    'uphold',
#    'death',
#    'sentence',
#    'accused',
#    'lawyer',
#    'autopsy',
#    'discovered',
#    'body',
#    'particularly',
#    'head',
#    'abdomen',
#    'resulting',
#    'strong',
#    'blunt',
#    'object',
#    'according',
#    'witness',
#    'employee',
#    'accused',
#    'stop',
#    'beating',
#    'victim',
#    'told',
#    'stay',
#    'family',
#    'said',
#    'meanwhile',
#    'court',
#    'aside',
#    'death',
#    'sentence',
#    'allow',
#    'review',
#    'client',
#    'deeply',
#    'suffering',
#    'several',
#    'antisocial',
#    'personality',
#    'disorder',
#    'hypertension',
#    'chronic',
#    'hepatitis',
#    'june',
#    'high',
#    'court',
#    'death',
#    'finding',
#    'guilty',
#    'murdering',
#    'aged',
#    'palm',
#    'plantation',
#    'pinang',
#    'appeal',
#    'court',
#    'appeal',
#    'federal',
#    'court',
#    'subsequently',
#    'upheld',
#    'conviction',
#    'sentence',
#    'according',
#    'case',
#    'incident',
#    'heading',
#    'workplace',
#    'victim',
#    'told',
#    'accused',
#    'urinate',
#    'defecate',
#    'hard',
#    'cheek',
#    'upon',
#    'location',
#    'victim',
#    'child',
#    'beat',
#    'repeatedly',
#    'tree',
#    'branch',
#    'child',
#    'took',
#    'child',
#    'hospital',
#    'pronounced',
#    'dead'],
#   'tokenised_headline': ['federal',
#    'court',
#    'death',
#    'sentence',
#    'murder',
#    'stepson'],
#   'author': '',
#   'datetime': '2024-07-16T21:09:28+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/federal-court-upholds-death-sentence-for-mans-murder-of-stepson/',
#   'category': 'murder and homicide'},
#  {'key': 'k10',
#   'tokenised_content': ['court',
#    'appeal',
#    'reduced',
#    'year',
#    'prison',
#    'sentence',
#    'physical',
#    'sexual',
#    'assault',
#    'three',
#    'young',
#    'however',
#    'panel',
#    'upheld',
#    'initially',
#    'session',
#    'court',
#    'father',
#    'panel',
#    'included',
#    'appeal',
#    'conviction',
#    'appeal',
#    'sentence',
#    'reduction',
#    'justice',
#    'said',
#    'adduce',
#    'session',
#    'high',
#    'court',
#    'also',
#    'lower',
#    'decision',
#    'former',
#    'driver',
#    'found',
#    'guilty',
#    'session',
#    'court',
#    'five',
#    'sexually',
#    'five',
#    'house',
#    'june',
#    'respectively',
#    'faced',
#    'sexually',
#    'similar',
#    'count',
#    'sexually',
#    'accused',
#    'total',
#    'prison',
#    'cane',
#    'march',
#    'last',
#    'year',
#    'high',
#    'court',
#    'conviction',
#    'sentence',
#    'eight',
#    'prison',
#    'cane',
#    'count',
#    'older',
#    'imprisonment',
#    'cane',
#    'daughter',
#    'today',
#    'court',
#    'appeal',
#    'reduced',
#    'initial',
#    'jail',
#    'term',
#    'year',
#    'imprisonment',
#    'eight',
#    'deputy',
#    'public',
#    'prosecutor',
#    'prosecution',
#    'lawyer',
#    'national',
#    'legal',
#    'foundation'],
#   'tokenised_headline': ['father', 'sexually', 'sentence', 'reduced'],
#   'author': '',
#   'datetime': '2024-07-16T19:12:29+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/father-convicted-of-sexually-assaulting-daughters-gets-sentence-reduced/',
#   'category': 'sexual harassment or sexual offences or rape'},
#  {'key': 'k11',
#   'tokenised_content': ['investment',
#    'consultant',
#    'guilty',
#    'session',
#    'court',
#    'today',
#    'four',
#    'money',
#    'nearly',
#    'million',
#    'last',
#    'year',
#    'nizam',
#    'plea',
#    'read',
#    'judge',
#    'according',
#    'owner',
#    'growth',
#    'venture',
#    'transferred',
#    'proceeds',
#    'unlawful',
#    'belonging',
#    'four',
#    'four',
#    'allegedly',
#    'bank',
#    'mall',
#    'branch',
#    'last',
#    'year',
#    'framed',
#    'section',
#    'proceeds',
#    'unlawful',
#    'imprisonment',
#    'also',
#    'five',
#    'time',
#    'amount',
#    'value',
#    'proceeds',
#    'unlawful',
#    'activity',
#    'million',
#    'whichever',
#    'higher',
#    'deputy',
#    'public',
#    'prosecutor',
#    'bail',
#    'charge',
#    'serious',
#    'public',
#    'concern',
#    'lawyer',
#    'pang',
#    'accused',
#    'lower',
#    'bail',
#    'client',
#    'struggling',
#    'find',
#    'case',
#    'three',
#    'aged',
#    'care',
#    'court',
#    'bail',
#    'surety',
#    'surety',
#    'charge',
#    'ordered',
#    'nizam',
#    'report',
#    'nearest',
#    'police',
#    'station',
#    'first',
#    'month',
#    'case',
#    'mention',
#    'august'],
#   'tokenised_headline': ['consultant', 'nearly'],
#   'author': '',
#   'datetime': '2024-07-16T17:08:37+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/consultant-charged-with-laundering-nearly-rm1-mln/',
#   'category': 'money laundering'},
#  {'key': 'k12',
#   'tokenised_content': ['police',
#    'eight',
#    'foreign',
#    'aged',
#    'investigation',
#    'death',
#    'foreign',
#    'factory',
#    'worker',
#    'last',
#    'district',
#    'police',
#    'chief',
#    'said',
#    'respective',
#    'baru',
#    'following',
#    'arrest',
#    'said',
#    'police',
#    'also',
#    'found',
#    'stick',
#    'used',
#    'victim',
#    'last',
#    'district',
#    'police',
#    'received',
#    'report',
#    'hospital',
#    'medical',
#    'officer',
#    'informed',
#    'foreign',
#    'nationality',
#    'sent',
#    'hospital',
#    'unconscious',
#    'state',
#    'bleeding',
#    'hand',
#    'said',
#    'statement',
#    'today',
#    'said',
#    'case',
#    'section',
#    'penal',
#    'code',
#    'advised',
#    'public',
#    'make',
#    'share',
#    'inaccurate',
#    'information',
#    'avoid',
#    'investigation',
#    'causing',
#    'public',
#    'annoyance'],
#   'tokenised_headline': ['arrest', 'eight', 'death', 'factory', 'worker'],
#   'author': '',
#   'datetime': '2024-07-14T14:40:55+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/cops-arrest-eight-foreigners-over-death-of-factory-worker-in-puchong/',
#   'category': 'murder and homicide'},
#  {'key': 'k14',
#   'tokenised_content': ['eighteen',
#    'foreign',
#    'woman',
#    'suspicion',
#    'involved',
#    'fraud',
#    'south',
#    'united',
#    'district',
#    'police',
#    'chief',
#    'said',
#    'local',
#    'local',
#    'woman',
#    'foreign',
#    'woman',
#    'condominium',
#    'police',
#    'also',
#    'equipment',
#    'mobile',
#    'raid',
#    'syndicate',
#    'getting',
#    'people',
#    'invest',
#    'nonexistent',
#    'investment',
#    'south',
#    'invite',
#    'invest',
#    'poly',
#    'platform',
#    'promising',
#    'return',
#    'cent',
#    'profit',
#    'however',
#    'receive',
#    'said',
#    'statement',
#    'today',
#    'said',
#    'carrying',
#    'past',
#    'three',
#    'received',
#    'payment',
#    'month',
#    'yesterday',
#    'value',
#    'ownership',
#    'still',
#    'police',
#    'investigation',
#    'said',
#    'case',
#    'section',
#    'penal',
#    'code',
#    'fraud'],
#   'tokenised_headline': ['involvement', 'scam'],
#   'author': '',
#   'datetime': '2024-07-12T16:07:23+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/cops-nab-18-for-alleged-involvement-in-online-forex-scam/',
#   'category': 'others'},
#  {'key': 'k15',
#   'tokenised_content': ['underage',
#    'girl',
#    'guilty',
#    'session',
#    'court',
#    'today',
#    'underage',
#    'sexual',
#    'exploitation',
#    'first',
#    'charge',
#    'friend',
#    'together',
#    'teenage',
#    'girl',
#    'sexual',
#    'exploitation',
#    'hotel',
#    'along',
#    'second',
#    'charge',
#    'accused',
#    'another',
#    'girl',
#    'separate',
#    'room',
#    'hotel',
#    'date',
#    'section',
#    'read',
#    'together',
#    'section',
#    'penal',
#    'code',
#    'life',
#    'imprisonment',
#    'imprisonment',
#    'period',
#    'five',
#    'whipped',
#    'deputy',
#    'public',
#    'prosecutor',
#    'handled',
#    'prosecution',
#    'case',
#    'accused',
#    'judge',
#    'accused',
#    'surety',
#    'first',
#    'charge',
#    'surety',
#    'second',
#    'charge',
#    'accused',
#    'also',
#    'subject',
#    'additional',
#    'nearest',
#    'police',
#    'station',
#    'every',
#    'month',
#    'approach',
#    'prosecution',
#    'court',
#    'fixed',
#    'august',
#    'case'],
#   'tokenised_headline': ['underage'],
#   'author': '',
#   'datetime': '2024-07-12T13:58:43+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/duo-charged-with-trafficking-underage-girls/',
#   'category': 'sexual harassment or sexual offences or rape'},
#  {'key': 'k16',
#   'tokenised_content': ['total',
#    'foreign',
#    'police',
#    'following',
#    'massage',
#    'valley',
#    'allegedly',
#    'employed',
#    'antivice',
#    'gambling',
#    'secret',
#    'division',
#    'principal',
#    'assistant',
#    'director',
#    'said',
#    'included',
#    'five',
#    'five',
#    'aged',
#    'nine',
#    'also',
#    'foreign',
#    'national',
#    'worked',
#    'counter',
#    'attendant',
#    'customer',
#    'massage',
#    'suspected',
#    'foreign',
#    'without',
#    'valid',
#    'providing',
#    'immoral',
#    'solely',
#    'regular',
#    'foreign',
#    'service',
#    'ranging',
#    'said',
#    'revealed',
#    'foreign',
#    'social',
#    'visit',
#    'identification',
#    'case',
#    'section',
#    'penal',
#    'code',
#    'immigration',
#    'separate',
#    'case',
#    'suspected',
#    'football',
#    'betting',
#    'yesterday',
#    'condominium',
#    'said',
#    'found',
#    'earning',
#    'month',
#    'betting',
#    'reportedly',
#    'earning',
#    'every'],
#   'tokenised_headline': ['police',
#    'detain',
#    'foreign',
#    'massage',
#    'crackdown'],
#   'author': '',
#   'datetime': '2024-07-07T16:34:14+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/police-detain-39-foreign-women-in-massage-parlour-crackdown/',
#   'category': 'sexual harassment or sexual offences or rape'},
#  {'key': 'k19',
#   'tokenised_content': ['former',
#    'scrap',
#    'metal',
#    'death',
#    'sentence',
#    'killing',
#    'transvestite',
#    'jail',
#    'federal',
#    'court',
#    'today',
#    'panel',
#    'chief',
#    'justice',
#    'tuan',
#    'federal',
#    'court',
#    'review',
#    'application',
#    'revision',
#    'sentence',
#    'death',
#    'imprisonment',
#    'natural',
#    'life',
#    'temporary',
#    'jurisdiction',
#    'federal',
#    'court',
#    'justice',
#    'ordered',
#    'prison',
#    'sentence',
#    'raja',
#    'begin',
#    'date',
#    'arrest',
#    'also',
#    'raja',
#    'found',
#    'guilty',
#    'high',
#    'court',
#    'killing',
#    'flood',
#    'retention',
#    'pond',
#    'august',
#    'overturn',
#    'conviction',
#    'death',
#    'sentence',
#    'court',
#    'appeal',
#    'federal',
#    'court',
#    'deputy',
#    'public',
#    'prosecutor',
#    'court',
#    'uphold',
#    'death',
#    'sentence',
#    'extremely',
#    'brutal',
#    'nature',
#    'murder',
#    'apparent',
#    'lack',
#    'motive',
#    'based',
#    'case',
#    'said',
#    'night',
#    'murder',
#    'raja',
#    'group',
#    'went',
#    'location',
#    'deceased',
#    'deceased',
#    'woman',
#    'worked',
#    'prostitute',
#    'forced',
#    'enter',
#    'sexual',
#    'intercourse',
#    'raja',
#    'later',
#    'knife',
#    'lawyer',
#    'court',
#    'give',
#    'client',
#    'chance',
#    'death',
#    'sentence',
#    'life',
#    'imprisonment',
#    'meanwhile',
#    'panel',
#    'death',
#    'sentence',
#    'jail',
#    'murdering',
#    'lover',
#    'review',
#    'application',
#    'justice',
#    'also',
#    'cane',
#    'jail',
#    'term',
#    'start',
#    'date',
#    'arrest',
#    'death',
#    'high',
#    'court',
#    'killing',
#    'also',
#    'house',
#    'court',
#    'appeal',
#    'federal',
#    'court',
#    'following',
#    'year',
#    'court',
#    'uphold',
#    'death',
#    'sentence',
#    'saying',
#    'deceased',
#    'struck',
#    'three',
#    'time',
#    'head',
#    'large',
#    'rock',
#    'however',
#    'lawyer',
#    'life',
#    'imprisonment',
#    'saying',
#    'crime',
#    'passion',
#    'added',
#    'client',
#    'deceased',
#    'struck',
#    'affair',
#    'another'],
#   'tokenised_headline': ['death', 'sentence', 'killing', 'jail'],
#   'author': '',
#   'datetime': '2024-07-04T19:05:03+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/mans-death-sentence-for-killing-transwoman-commuted-to-38-years-jail/',
#   'category': 'murder and homicide'},
#  {'key': 'k20',
#   'tokenised_content': ['former',
#    'construction',
#    'renovation',
#    'company',
#    'owner',
#    'prison',
#    'session',
#    'court',
#    'today',
#    'guilty',
#    'transferring',
#    'million',
#    'belonging',
#    'woman',
#    'related',
#    'offer',
#    'judge',
#    'admitted',
#    'transferring',
#    'belonging',
#    'boon',
#    'bank',
#    'account',
#    'company',
#    'renovation',
#    'premise',
#    'section',
#    'penal',
#    'code',
#    'maximum',
#    'sentence',
#    'five',
#    'prison',
#    'fine',
#    'subsequently',
#    'prison',
#    'pleading',
#    'guilty',
#    'belonging',
#    'soon',
#    'transferred',
#    'money',
#    'bank',
#    'account',
#    'section',
#    'ordered',
#    'prison',
#    'concurrently',
#    'date',
#    'arrest',
#    'june',
#    'also',
#    'ordered',
#    'begin',
#    'prison',
#    'sentence',
#    'date',
#    'case',
#    'handled',
#    'deputy',
#    'public',
#    'prosecutor',
#    'accused',
#    'unrepresented',
#    'separate',
#    'session',
#    'court',
#    'judge',
#    'prison',
#    'guilty',
#    'similar',
#    'belonging',
#    'victim',
#    'ordered',
#    'sentence',
#    'begin',
#    'immediately',
#    'deputy',
#    'public',
#    'prosecutor',
#    'amir',
#    'prosecution',
#    'according',
#    'case',
#    'victim',
#    'come',
#    'across',
#    'offer',
#    'page',
#    'account',
#    'task',
#    'book',
#    'account',
#    'balance',
#    'insufficient',
#    'first',
#    'task',
#    'received',
#    'return',
#    'money',
#    'believe',
#    'legitimate',
#    'consequently',
#    'made',
#    'several',
#    'bank',
#    'account',
#    'later',
#    'money',
#    'returned',
#    'investigating',
#    'also',
#    'million',
#    'victim',
#    'avoid',
#    'accused',
#    'later',
#    'explain',
#    'company',
#    'bank',
#    'account'],
#   'tokenised_headline': ['former', 'company', 'owner'],
#   'author': '',
#   'datetime': '2024-07-03T23:08:01+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/former-company-owner-jailed-six-months-for-concealing-womans-rm1-3-mln/',
#   'category': 'money laundering'},
#  {'key': 'k21',
#   'tokenised_content': ['unemployed',
#    'police',
#    'officer',
#    'year',
#    'jail',
#    'three',
#    'cane',
#    'session',
#    'court',
#    'today',
#    'robbery',
#    'judge',
#    'handed',
#    'sentence',
#    'guilty',
#    'charge',
#    'robbing',
#    'mobile',
#    'card',
#    'belonging',
#    'last',
#    'year',
#    'section',
#    'penal',
#    'code',
#    'maximum',
#    'prison',
#    'sentence',
#    'fine',
#    'whipping',
#    'upon',
#    'conviction',
#    'based',
#    'case',
#    'accused',
#    'police',
#    'officer',
#    'stopped',
#    'riding',
#    'bicycle',
#    'deputy',
#    'public',
#    'prosecutor',
#    'prosecution',
#    'unrepresented'],
#   'tokenised_headline': ['unemployed', 'robbing', 'policeman'],
#   'author': '',
#   'datetime': '2024-07-03T19:18:44+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/unemployed-man-jailed-for-robbing-boy-impersonating-policeman/',
#   'category': 'robbery or theft'},
#  {'key': 'k22',
#   'tokenised_content': ['disabled',
#    'court',
#    'today',
#    'murder',
#    'mother',
#    'last',
#    'month',
#    'charge',
#    'read',
#    'magistrate',
#    'however',
#    'plea',
#    'murder',
#    'fall',
#    'jurisdiction',
#    'high',
#    'court',
#    'accused',
#    'causing',
#    'death',
#    'chew',
#    'housing',
#    'estate',
#    'june',
#    'section',
#    'penal',
#    'code',
#    'death',
#    'penalty',
#    'upon',
#    'conviction',
#    'deputy',
#    'public',
#    'prosecutor',
#    'accused',
#    'sent',
#    'hospital',
#    'mental',
#    'assessment',
#    'section',
#    'criminal',
#    'procedure',
#    'code',
#    'request',
#    'determine',
#    'mental',
#    'case',
#    'mention',
#    'august',
#    'june',
#    'district',
#    'police',
#    'chief',
#    'chang',
#    'hook',
#    'said',
#    'accused',
#    'disabled',
#    'card',
#    'mother',
#    'elderly',
#    'woman',
#    'found',
#    'unconscious',
#    'compound'],
#   'tokenised_headline': ['disabled', 'matricide'],
#   'author': '',
#   'datetime': '2024-07-03T19:13:50+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/disabled-man-charged-with-matricide/',
#   'category': 'murder and homicide'},
#  {'key': 'k23',
#   'tokenised_content': ['woman',
#    'lost',
#    'million',
#    'falling',
#    'victim',
#    'nonexistent',
#    'investment',
#    'scheme',
#    'police',
#    'chief',
#    'said',
#    'victim',
#    'advertisement',
#    'financial',
#    'success',
#    'last',
#    'year',
#    'filled',
#    'form',
#    'individual',
#    'victim',
#    'join',
#    'group',
#    'related',
#    'share',
#    'management',
#    'individual',
#    'three',
#    'victim',
#    'join',
#    'another',
#    'group',
#    'several',
#    'taught',
#    'victim',
#    'invest',
#    'made',
#    'cash',
#    'bank',
#    'account',
#    'number',
#    'given',
#    'said',
#    'statement',
#    'today',
#    'said',
#    'unemployed',
#    'victim',
#    'made',
#    'several',
#    'march',
#    'june',
#    'money',
#    'family',
#    'sale',
#    'asset',
#    'lucrative',
#    'million',
#    'short',
#    'period',
#    'today',
#    'victim',
#    'received',
#    'voice',
#    'blocked',
#    'lodged',
#    'report',
#    'district',
#    'police',
#    'headquarters',
#    'said'],
#   'tokenised_headline': ['woman', 'investment', 'scam'],
#   'author': '',
#   'datetime': '2024-07-03T19:12:20+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/woman-duped-of-rm1-6-mln-in-cryptocurrency-investment-scam/',
#   'category': 'scam'},
#  {'key': 'k24',
#   'tokenised_content': ['high',
#    'court',
#    'former',
#    'prime',
#    'minister',
#    'legal',
#    'obtain',
#    'document',
#    'said',
#    'allow',
#    'serve',
#    'prison',
#    'sentence',
#    'house',
#    'arrest',
#    'judicial',
#    'review',
#    'application',
#    'said',
#    'addendum',
#    'order',
#    'former',
#    'king',
#    'decision',
#    'halve',
#    'year',
#    'jail',
#    'sentence',
#    'graft',
#    'development',
#    'scandal',
#    'sought',
#    'court',
#    'compel',
#    'government',
#    'reply',
#    'confirm',
#    'existence',
#    'royal',
#    'order',
#    'said',
#    'entitle',
#    'serve',
#    'remainder',
#    'term',
#    'house',
#    'arrest',
#    'execute',
#    'order',
#    'copy',
#    'judgment',
#    'medium',
#    'today',
#    'high',
#    'court',
#    'found',
#    'arguable',
#    'case',
#    'full',
#    'hearing',
#    'application',
#    'judge',
#    'singh',
#    'deputy',
#    'prime',
#    'minister',
#    'another',
#    'politician',
#    'party',
#    'saying',
#    'seen',
#    'copy',
#    'royal',
#    'order',
#    'hearsay',
#    'said',
#    'government',
#    'legal',
#    'duty',
#    'respond',
#    'application',
#    'appeal',
#    'decision',
#    'lawyer',
#    'told',
#    'ethic',
#    'government',
#    'said',
#    'board',
#    'halved',
#    'term',
#    'former',
#    'yang',
#    'shah',
#    'whose',
#    'reign',
#    'king',
#    'ended',
#    'found',
#    'guilty',
#    'criminal',
#    'breach',
#    'trust',
#    'abuse',
#    'power',
#    'illegally',
#    'fund',
#    'unit',
#    'state',
#    'fund',
#    'verdict',
#    'upheld',
#    'federal',
#    'court',
#    'united',
#    'estimate',
#    'billion',
#    'billion',
#    'stolen',
#    'billion',
#    'channelled',
#    'linked',
#    'board',
#    'said',
#    'august',
#    'serving',
#    'sentence',
#    'also',
#    'reduced',
#    'minister',
#    'sparking',
#    'uproar',
#    'among',
#    'also',
#    'considering',
#    'filing',
#    'petition',
#    'full',
#    'pardon',
#    'remains',
#    'trial',
#    'corruption',
#    'several'],
#   'tokenised_headline': ['legal', 'serve', 'sentence', 'house', 'arrest'],
#   'author': '',
#   'datetime': '2024-07-03T12:18:42+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/ex-pm-najib-loses-legal-bid-to-serve-sentence-under-house-arrest/',
#   'category': 'others'},
#  {'key': 'k25',
#   'tokenised_content': ['shah',
#    'police',
#    'luxury',
#    'theft',
#    'syndicate',
#    'known',
#    'arrest',
#    'seven',
#    'series',
#    'around',
#    'june',
#    'june',
#    'police',
#    'chief',
#    'khan',
#    'said',
#    'aged',
#    'police',
#    'received',
#    'report',
#    'june',
#    'rented',
#    'house',
#    'broken',
#    'making',
#    'three',
#    'namely',
#    'cayman',
#    'swift',
#    'time',
#    'incident',
#    'employer',
#    'said',
#    'china',
#    'around',
#    'told',
#    'press',
#    'conference',
#    'contingent',
#    'police',
#    'headquarters',
#    'today',
#    'based',
#    'information',
#    'received',
#    'police',
#    'series',
#    'resulting',
#    'arrest',
#    'mastermind',
#    'initial',
#    'found',
#    'mastermind',
#    'aged',
#    'prior',
#    'drug',
#    'criminal',
#    'group',
#    'active',
#    'past',
#    'year',
#    'identify',
#    'luxury',
#    'breaking',
#    'stealing',
#    'addition',
#    'sold',
#    'used',
#    'criminal',
#    'said',
#    'following',
#    'police',
#    'four',
#    'luxury',
#    'three',
#    'stolen',
#    'incident',
#    'well',
#    'various',
#    'used',
#    'criminal',
#    'tomorrow',
#    'case',
#    'section',
#    'section',
#    'penal',
#    'code'],
#   'tokenised_headline': ['police',
#    'bust',
#    'luxury',
#    'vehicle',
#    'theft',
#    'ring',
#    'seven'],
#   'author': '',
#   'datetime': '2024-07-02T19:20:22+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/police-bust-luxury-vehicle-theft-ring-seven-nabbed/',
#   'category': 'robbery or theft'},
#  {'key': 'k27',
#   'tokenised_content': ['rider',
#    'four',
#    'imprisonment',
#    'session',
#    'court',
#    'today',
#    'pleading',
#    'guilty',
#    'charge',
#    'dishonestly',
#    'helping',
#    'conceal',
#    'belonging',
#    'elderly',
#    'woman',
#    'judge',
#    'handed',
#    'sentence',
#    'cheng',
#    'ordered',
#    'serve',
#    'sentence',
#    'date',
#    'arrest',
#    'yesterday',
#    'accused',
#    'belonging',
#    'money',
#    'bank',
#    'account',
#    'registered',
#    'name',
#    'charge',
#    'framed',
#    'section',
#    'penal',
#    'code',
#    'imprisonment',
#    'five',
#    'fine',
#    'mitigation',
#    'cheng',
#    'unrepresented',
#    'said',
#    'five',
#    'disabled',
#    'husband',
#    'support',
#    'deputy',
#    'public',
#    'prosecutor',
#    'amir',
#    'prosecution'],
#   'tokenised_headline': ['rider', 'elderly'],
#   'author': '',
#   'datetime': '2024-07-02T15:18:38+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/despatch-rider-jailed-for-concealing-elderly-womans-rm100000/',
#   'category': 'others'},
#  {'key': 'k28',
#   'tokenised_content': ['suspected',
#    'drug',
#    'addict',
#    'chase',
#    'police',
#    'yesterday',
#    'district',
#    'police',
#    'chief',
#    'said',
#    'ordered',
#    'suspect',
#    'wheel',
#    'stop',
#    'vehicle',
#    'spotted',
#    'suspicious',
#    'manner',
#    'sped',
#    'police',
#    'mobile',
#    'patrol',
#    'vehicle',
#    'suspect',
#    'three',
#    'arresting',
#    'suspect',
#    'crash',
#    'driven',
#    'suspect',
#    'police',
#    'said',
#    'statement',
#    'today',
#    'preliminary',
#    'investigation',
#    'found',
#    'suspect',
#    'previous',
#    'tested',
#    'positive',
#    'amphetamine',
#    'case',
#    'section',
#    'section',
#    'penal',
#    'code',
#    'public',
#    'speculate',
#    'incident'],
#   'tokenised_headline': ['suspected', 'drug', 'addict', 'chase'],
#   'author': '',
#   'datetime': '2024-07-02T15:07:21+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/07/suspected-drug-addict-arrested-after-three-km-chase/',
#   'category': 'drug offences'},
#  {'key': 'k32',
#   'tokenised_content': ['june',
#    'court',
#    'appeal',
#    'death',
#    'sentence',
#    'former',
#    'worker',
#    'today',
#    'jail',
#    'court',
#    'also',
#    'ordered',
#    'given',
#    'rotan',
#    'court',
#    'panel',
#    'ordered',
#    'accused',
#    'serve',
#    'sentence',
#    'concurrently',
#    'date',
#    'arrest',
#    'march',
#    'justice',
#    'decision',
#    'said',
#    'based',
#    'submission',
#    'lawyer',
#    'singh',
#    'court',
#    'decided',
#    'uphold',
#    'conviction',
#    'however',
#    'court',
#    'discretion',
#    'substitute',
#    'death',
#    'sentence',
#    'life',
#    'imprisonment',
#    'rotan',
#    'high',
#    'court',
#    'death',
#    'finding',
#    'guilty',
#    'drug',
#    'house',
#    'march',
#    'parking',
#    'time'],
#   'tokenised_headline': ['death', 'sentence'],
#   'author': '',
#   'datetime': '2024-06-26T19:13:21+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/06/ex-odd-jobbers-death-sentence-commuted-for-trafficking-over-200kg-of-cannabis/',
#   'category': 'drug offences'},
#  {'key': 'k33',
#   'tokenised_content': ['june',
#    'clerk',
#    'firm',
#    'guilty',
#    'court',
#    'today',
#    'lawyer',
#    'giving',
#    'false',
#    'evidence',
#    'regarding',
#    'bank',
#    'document',
#    'court',
#    'proceeding',
#    'accused',
#    'title',
#    'lawyer',
#    'firm',
#    'qualified',
#    'solicitor',
#    'restaurant',
#    'charge',
#    'section',
#    'legal',
#    'profession',
#    'punishable',
#    'section',
#    'maximum',
#    'fine',
#    'imprisonment',
#    'upon',
#    'conviction',
#    'accused',
#    'also',
#    'giving',
#    'false',
#    'evidence',
#    'concerning',
#    'bank',
#    'document',
#    'trial',
#    'case',
#    'civil',
#    'high',
#    'court',
#    'judge',
#    'charge',
#    'framed',
#    'section',
#    'penal',
#    'code',
#    'maximum',
#    'imprisonment',
#    'seven',
#    'fine',
#    'magistrate',
#    'accused',
#    'bail',
#    'surety',
#    'august',
#    'mention',
#    'case',
#    'document',
#    'submission'],
#   'tokenised_headline': ['clerk', 'lawyer', 'giving', 'false', 'evidence'],
#   'author': '',
#   'datetime': '2024-06-26T19:10:59+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/06/clerk-charged-with-impersonating-lawyer-giving-false-evidence/',
#   'category': 'others'},
#  {'key': 'k37',
#   'tokenised_content': ['june',
#    'restaurant',
#    'worker',
#    'session',
#    'court',
#    'today',
#    'three',
#    'understanding',
#    'read',
#    'judge',
#    'however',
#    'plea',
#    'case',
#    'come',
#    'jurisdiction',
#    'high',
#    'court',
#    'accused',
#    'supporting',
#    'account',
#    'bearing',
#    'name',
#    'telegram',
#    'bearing',
#    'name',
#    'special',
#    'terrorism',
#    'division',
#    'police',
#    'headquarters',
#    'charge',
#    'framed',
#    'section',
#    'penal',
#    'code',
#    'maximum',
#    'prison',
#    'sentence',
#    'fine',
#    'forfeiture',
#    'property',
#    'used',
#    'intended',
#    'used',
#    'upon',
#    'conviction',
#    'second',
#    'charge',
#    'accused',
#    'possessing',
#    'related',
#    'location',
#    'date',
#    'time',
#    'charge',
#    'framed',
#    'section',
#    'penal',
#    'code',
#    'maximum',
#    'imprisonment',
#    'seven',
#    'fine',
#    'forfeiture',
#    'property',
#    'used',
#    'intended',
#    'upon',
#    'conviction',
#    'accused',
#    'also',
#    'admitted',
#    'member',
#    'group',
#    'pledge',
#    'allegiance',
#    'ceremony',
#    'group',
#    'support',
#    'terrorist',
#    'group',
#    'apartment',
#    'unit',
#    'year',
#    'charge',
#    'framed',
#    'section',
#    'penal',
#    'code',
#    'life',
#    'imprisonment',
#    'maximum',
#    'imprisonment',
#    'fine',
#    'forfeiture',
#    'property',
#    'used',
#    'intended',
#    'used',
#    'commit',
#    'deputy',
#    'public',
#    'prosecutor',
#    'court',
#    'date',
#    'within',
#    'next',
#    'submit',
#    'report',
#    'expert',
#    'regarding',
#    'related',
#    'terrorist',
#    'group',
#    'court',
#    'court',
#    'august',
#    'submission',
#    'related',
#    'case'],
#   'tokenised_headline': ['three'],
#   'author': '',
#   'datetime': '2024-06-25T15:21:19+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/06/man-charged-with-three-counts-of-terrorism-related-offences/',
#   'category': 'firearm or terrorism'},
#  {'key': 'k38',
#   'tokenised_content': ['june',
#    'unemployed',
#    'court',
#    'today',
#    'murdering',
#    'mother',
#    'house',
#    'june',
#    'sugan',
#    'understanding',
#    'charge',
#    'read',
#    'magistrate',
#    'plea',
#    'murder',
#    'fall',
#    'jurisdiction',
#    'high',
#    'court',
#    'accused',
#    'killing',
#    'house',
#    'june',
#    'charge',
#    'section',
#    'penal',
#    'code',
#    'death',
#    'penalty',
#    'imprisonment',
#    'cane',
#    'upon',
#    'conviction',
#    'deputy',
#    'public',
#    'prosecutor',
#    'accused',
#    'unrepresented',
#    'court',
#    'fixed',
#    'august',
#    'mention',
#    'previously',
#    'body',
#    'elderly',
#    'woman',
#    'found',
#    'covered',
#    'blood',
#    'house',
#    'revealed',
#    'head',
#    'neck',
#    'blunt',
#    'trauma',
#    'leading',
#    'case',
#    'classified',
#    'murder'],
#   'tokenised_headline': ['unemployed', 'matricide'],
#   'author': '',
#   'datetime': '2024-06-25T15:09:24+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/06/unemployed-man-charged-with-matricide/',
#   'category': 'murder and homicide'},
#  {'key': 'k39',
#   'tokenised_content': ['june',
#    'court',
#    'appeal',
#    'today',
#    'death',
#    'sentence',
#    'jail',
#    'murdering',
#    'house',
#    'cleaner',
#    'allegedly',
#    'three',
#    'judge',
#    'panel',
#    'judge',
#    'along',
#    'appeal',
#    'overturn',
#    'conviction',
#    'court',
#    'allow',
#    'appeal',
#    'commute',
#    'death',
#    'sentence',
#    'high',
#    'court',
#    'jail',
#    'date',
#    'arrest',
#    'also',
#    'cane',
#    'decision',
#    'justice',
#    'said',
#    'unsound',
#    'mind',
#    'knew',
#    'nature',
#    'conduct',
#    'fact',
#    'murder',
#    'counsel',
#    'court',
#    'commute',
#    'death',
#    'sentence',
#    'jail',
#    'deputy',
#    'public',
#    'prosecutor',
#    'court',
#    'uphold',
#    'death',
#    'sentence',
#    'found',
#    'guilty',
#    'high',
#    'court',
#    'last',
#    'year',
#    'killing',
#    'house',
#    'district',
#    'high',
#    'court',
#    'judge',
#    'tiang',
#    'prove',
#    'unsound',
#    'mind',
#    'incapable',
#    'knowing',
#    'nature',
#    'time',
#    'killing'],
#   'tokenised_headline': ['death', 'sentence', 'murderer', 'jail'],
#   'author': '',
#   'datetime': '2024-06-24T21:04:41+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/06/death-sentence-for-indonesian-cleaners-murderer-commuted-to-35-years-jail/',
#   'category': 'murder and homicide'},
#  {'key': 'k40',
#   'tokenised_content': ['june',
#    'five',
#    'robbery',
#    'gang',
#    'known',
#    'trio',
#    'nine',
#    'imprisonment',
#    'court',
#    'today',
#    'pleading',
#    'guilty',
#    'three',
#    'robbery',
#    'magistrate',
#    'handed',
#    'sentence',
#    'three',
#    'jail',
#    'count',
#    'however',
#    'magistrate',
#    'ordered',
#    'serve',
#    'jail',
#    'concurrently',
#    'date',
#    'arrest',
#    'march',
#    'based',
#    'three',
#    'five',
#    'robbing',
#    'three',
#    'gold',
#    'worth',
#    'belonging',
#    'three',
#    'separate',
#    'namely',
#    'dang',
#    'section',
#    'penal',
#    'code',
#    'imprisonment',
#    'fine',
#    'upon',
#    'conviction',
#    'deputy',
#    'public',
#    'prosecutor',
#    'amir',
#    'prosecution',
#    'lawyer',
#    'jean',
#    'national',
#    'legal',
#    'foundation',
#    'five',
#    'accused',
#    'another',
#    'court',
#    'five',
#    'accused',
#    'three',
#    'jail',
#    'similar',
#    'magistrate',
#    'handed',
#    'sentence',
#    'guilty',
#    'robbery',
#    'bandar',
#    'baru',
#    'also',
#    'another',
#    'three',
#    'imprisonment',
#    'also',
#    'robbery',
#    'dental',
#    'faculty',
#    'medical',
#    'deputy',
#    'public',
#    'prosecutor',
#    'case',
#    'lawyer',
#    'singh',
#    'accused'],
#   'tokenised_headline': ['five', 'trio', 'three', 'robbery'],
#   'author': '',
#   'datetime': '2024-06-24T17:15:51+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/06/five-geng-trio-members-jailed-three-months-for-robbery/',
#   'category': 'robbery or theft'},
#  {'key': 'k41',
#   'tokenised_content': ['town',
#    'june',
#    'court',
#    'ordered',
#    'murder',
#    'mother',
#    'hospital',
#    'mental',
#    'observation',
#    'magistrate',
#    'application',
#    'deputy',
#    'public',
#    'prosecutor',
#    'today',
#    'ordered',
#    'soon',
#    'sent',
#    'hospital',
#    'month',
#    'observation',
#    'section',
#    'criminal',
#    'procedure',
#    'code',
#    'soon',
#    'section',
#    'penal',
#    'code',
#    'murdering',
#    'ting',
#    'house',
#    'vista',
#    'june',
#    'death',
#    'penalty',
#    'imprisonment',
#    'minimum',
#    'maximum',
#    'given',
#    'least',
#    'cane',
#    'accused',
#    'sent',
#    'psychiatric',
#    'observation',
#    'said',
#    'accused',
#    'holder',
#    'card',
#    'mental',
#    'court',
#    'mention',
#    'submission',
#    'medical',
#    'report'],
#   'tokenised_headline': ['matricide', 'sent', 'mental', 'asylum'],
#   'author': '',
#   'datetime': '2024-06-24T17:13:43+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/06/man-charged-with-matricide-sent-to-mental-asylum/',
#   'category': 'murder and homicide'},
#  {'key': 'k43',
#   'tokenised_content': ['june',
#    'police',
#    'station',
#    'murdering',
#    'wife',
#    'hotel',
#    'room',
#    'today',
#    'police',
#    'chief',
#    'said',
#    'suspect',
#    'police',
#    'station',
#    'based',
#    'information',
#    'police',
#    'found',
#    'victim',
#    'stab',
#    'wound',
#    'hotel',
#    'room',
#    'knife',
#    'used',
#    'suspect',
#    'found',
#    'scene',
#    'said',
#    'statement',
#    'today',
#    'initial',
#    'revealed',
#    'motive',
#    'murder',
#    'dissatisfaction',
#    'decision',
#    'proceed',
#    'divorce',
#    'request',
#    'suspect',
#    'victim',
#    'hotel',
#    'separately',
#    'stayed',
#    'room',
#    'incident',
#    'suspect',
#    'case',
#    'section',
#    'penal',
#    'code',
#    'said',
#    'anyone',
#    'information',
#    'contact',
#    'senior',
#    'investigating',
#    'officer',
#    'assist',
#    'investigation'],
#   'tokenised_headline': ['police', 'murdering', 'wife', 'hotel'],
#   'author': '',
#   'datetime': '2024-06-20T23:04:30+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/06/man-surrenders-to-police-after-murdering-wife-in-hotel/',
#   'category': 'murder and homicide'},
#  {'key': 'k46',
#   'tokenised_content': ['june',
#    'former',
#    'finance',
#    'human',
#    'manager',
#    'public',
#    'company',
#    'guilty',
#    'session',
#    'court',
#    'today',
#    'three',
#    'criminal',
#    'breach',
#    'trust',
#    'year',
#    'according',
#    'tong',
#    'group',
#    'allegedly',
#    'company',
#    'fund',
#    'making',
#    'bank',
#    'account',
#    'personal',
#    'accused',
#    'group',
#    'year',
#    'section',
#    'penal',
#    'code',
#    'maximum',
#    'penalty',
#    'imprisonment',
#    'fine',
#    'upon',
#    'conviction',
#    'also',
#    'guilty',
#    'three',
#    'alternative',
#    'fund',
#    'knowing',
#    'location',
#    'time',
#    'three',
#    'framed',
#    'section',
#    'penal',
#    'code',
#    'upon',
#    'conviction',
#    'maximum',
#    'sentence',
#    'five',
#    'imprisonment',
#    'fine',
#    'deputy',
#    'public',
#    'prosecutor',
#    'bail',
#    'surety',
#    'however',
#    'lawyer',
#    'read',
#    'lower',
#    'client',
#    'unemployed',
#    'wife',
#    'schoolgoing',
#    'judge',
#    'bail',
#    'surety',
#    'case',
#    'mention'],
#   'tokenised_headline': ['former', 'finance', 'manager', 'half'],
#   'author': '',
#   'datetime': '2024-06-18T17:10:04+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2024/06/former-finance-hr-manager-charged-with-over-half-mln-in-cbt/',
#   'category': 'others'},
#  {'key': 'k47',
#   'tokenised_content': ['june',
#    'elderly',
#    'accountant',
#    'lost',
#    'million',
#    'investment',
#    'syndicate',
#    'purchase',
#    'police',
#    'chief',
#    'said',
#    'lodged',
#    'police',
#    'report',
#    'yesterday',
#    'involved',
#    'scam',
#    'since',
#    'last',
#    'year',
#    'received',
#    'provided',
#    'information',
#    'invest',
#    'good',
#    'return',
#    'short',
#    'time',
#    'offer',
#    'victim',
#    'registered',
#    'bank',
#    'account',
#    'monitor',
#    'investment',
#    'said',
#    'statement',
#    'today',
#    'victim',
#    'making',
#    'several',
#    'starting',
#    'last',
#    'month',
#    'beginning',
#    'month',
#    'total',
#    'amount',
#    'transferred',
#    'exceeding',
#    'million',
#    'added',
#    'victim',
#    'later',
#    'informed',
#    'syndicate',
#    'profit',
#    'million',
#    'result',
#    'investment',
#    'commission',
#    'million',
#    'access',
#    'profit',
#    'victim',
#    'commission',
#    'suspected',
#    'fake',
#    'investment',
#    'syndicate',
#    'said',
#    'case',
#    'section',
#    'penal',
#    'code'],
#   'tokenised_headline': ['elderly', 'million', 'investment', 'scam'],
#   'author': '',
# ...
#    'framed',
#    'section',
#    'penal',
#    'code',
#    'death',
#    'sentence',
#    'upon',
#    'conviction',
#    'prosecution',
#    'deputy',
#    'public',
#    'prosecutor',
#    'couple',
#    'unrepresented'],
#   'tokenised_headline': ['june', 'mention', 'couple', 'murdering'],
#   'author': '',
#   'datetime': '2022-05-09T13:17:12+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/05/june-21-for-mention-of-couple-charged-with-murdering-four-year-old-boy/',
#   'category': 'murder and homicide'},
#  {'key': 'k1619',
#   'tokenised_content': ['police',
#    'assist',
#    'investigation',
#    'robbery',
#    'television',
#    'news',
#    'presenter',
#    'deputy',
#    'police',
#    'chief',
#    'said',
#    'local',
#    'sister',
#    'yesterday',
#    'said',
#    'revealed',
#    'male',
#    'suspect',
#    'past',
#    'criminal',
#    'also',
#    'person',
#    'female',
#    'suspect',
#    'criminal',
#    'record',
#    'according',
#    'several',
#    'case',
#    'robbery',
#    'used',
#    'suspect',
#    'crime',
#    'brought',
#    'court',
#    'tomorrow',
#    'remand',
#    'application',
#    'complete',
#    'investigation',
#    'said',
#    'statement',
#    'today',
#    'said',
#    'case',
#    'section',
#    'penal',
#    'code',
#    'robbery',
#    'resulting',
#    'injury',
#    'said',
#    'incident',
#    'roadside',
#    'near',
#    'broken',
#    'suspect',
#    'allegedly',
#    'front',
#    'passenger',
#    'side',
#    'window',
#    'steal',
#    'belonging',
#    'complainant',
#    'well',
#    'personal',
#    'scene',
#    'presence',
#    'said',
#    'complainant',
#    'went',
#    'suspect',
#    'following',
#    'scuffle',
#    'broke',
#    'fell',
#    'added',
#    'complainant',
#    'sustained',
#    'minor',
#    'loss',
#    'previously',
#    'second',
#    'video',
#    'clip',
#    'chase',
#    'user',
#    'scene',
#    'went',
#    'viral',
#    'social',
#    'medium'],
#   'tokenised_headline': ['robbery', 'case', 'news', 'presenter'],
#   'author': '',
#   'datetime': '2022-05-07T10:52:47+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/05/cops-nab-two-siblings-over-robbery-case-involving-news-presenter/',
#   'category': 'robbery or theft'},
#  {'key': 'k1620',
#   'tokenised_content': ['woman',
#    'allegedly',
#    'beaten',
#    'death',
#    'husband',
#    'revealing',
#    'affair',
#    'social',
#    'medium',
#    'incident',
#    'flat',
#    'raya',
#    'police',
#    'chief',
#    'said',
#    'victim',
#    'husband',
#    'blunt',
#    'object',
#    'said',
#    'husband',
#    'house',
#    'following',
#    'report',
#    'lodged',
#    'medical',
#    'officer',
#    'hospital',
#    'police',
#    'received',
#    'police',
#    'report',
#    'medical',
#    'officer',
#    'duty',
#    'hospital',
#    'received',
#    'unconscious',
#    'woman',
#    'sent',
#    'hospital',
#    'husband',
#    'later',
#    'confirmed',
#    'dead',
#    'said',
#    'statement',
#    'yesterday',
#    'said',
#    'external',
#    'examination',
#    'medical',
#    'officer',
#    'victim',
#    'found',
#    'several',
#    'death',
#    'suspicious',
#    'post',
#    'examination',
#    'revealed',
#    'cause',
#    'death',
#    'abdominal',
#    'injury',
#    'strong',
#    'blow',
#    'blunt',
#    'object',
#    'motive',
#    'murder',
#    'suspect',
#    'angry',
#    'victim',
#    'social',
#    'medium',
#    'suspect',
#    'affair',
#    'said',
#    'added',
#    'case',
#    'public',
#    'prosecutor',
#    'suspect',
#    'section',
#    'penal',
#    'code',
#    'court'],
#   'tokenised_headline': ['woman',
#    'allegedly',
#    'husband',
#    'revealing',
#    'affair',
#    'social',
#    'medium'],
#   'author': '',
#   'datetime': '2022-05-07T10:44:35+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/05/woman-allegedly-killed-by-husband-for-revealing-his-affair-on-social-media/',
#   'category': 'murder and homicide'},
#  {'key': 'k1624',
#   'tokenised_content': ['local',
#    'found',
#    'dead',
#    'gunshot',
#    'wound',
#    'forehead',
#    'hotel',
#    'room',
#    'yesterday',
#    'afternoon',
#    'hour',
#    'checked',
#    'criminal',
#    'investigation',
#    'department',
#    'chief',
#    'said',
#    'incident',
#    'discovered',
#    'hotel',
#    'employee',
#    'entry',
#    'room',
#    'police',
#    'victim',
#    'checked',
#    'hotel',
#    'police',
#    'roommate',
#    'investigation',
#    'said',
#    'said',
#    'apparent',
#    'motive',
#    'incident',
#    'firearm',
#    'used',
#    'found',
#    'case',
#    'section',
#    'penal',
#    'code',
#    'murder',
#    'said'],
#   'tokenised_headline': ['found',
#    'dead',
#    'hotel',
#    'room',
#    'gunshot',
#    'wound',
#    'head'],
#   'author': '',
#   'datetime': '2022-05-04T11:09:00+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/05/man-found-dead-in-hotel-room-with-gunshot-wound-to-head/',
#   'category': 'murder and homicide'},
#  {'key': 'k1625',
#   'tokenised_content': ['human',
#    'resource',
#    'manager',
#    'lost',
#    'scam',
#    'syndicate',
#    'syndicate',
#    'member',
#    'allegedly',
#    'extra',
#    'supply',
#    'community',
#    'clinic',
#    'commercial',
#    'crime',
#    'investigation',
#    'department',
#    'head',
#    'said',
#    'woman',
#    'working',
#    'private',
#    'company',
#    'received',
#    'call',
#    'health',
#    'ministry',
#    'official',
#    'supply',
#    'enforcement',
#    'division',
#    'victim',
#    'whether',
#    'extra',
#    'supply',
#    'cough',
#    'medicine',
#    'medicine',
#    'community',
#    'clinic',
#    'victim',
#    'allegation',
#    'call',
#    'connected',
#    'another',
#    'police',
#    'officer',
#    'told',
#    'victim',
#    'record',
#    'involved',
#    'money',
#    'said',
#    'statement',
#    'today',
#    'said',
#    'victim',
#    'also',
#    'thought',
#    'confess',
#    'arrest',
#    'warrant',
#    'said',
#    'victim',
#    'panicked',
#    'made',
#    'money',
#    'five',
#    'time',
#    'account',
#    'added',
#    'suspect',
#    'also',
#    'victim',
#    'wait',
#    'investigation',
#    'received',
#    'phone',
#    'call',
#    'make',
#    'additional',
#    'payment',
#    'victim',
#    'lodged',
#    'police',
#    'report',
#    'suspect',
#    'tracked',
#    'case',
#    'section',
#    'penal',
#    'code',
#    'cheating',
#    'said',
#    'also',
#    'advised',
#    'public',
#    'check',
#    'bank',
#    'suspicious',
#    'telephone',
#    'report',
#    'crime',
#    'suspicious',
#    'activity',
#    'contact',
#    'police',
#    'nearby',
#    'police',
#    'station'],
#   'tokenised_headline': ['company', 'manager', 'scam'],
#   'author': '',
#   'datetime': '2022-05-03T18:16:19+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/05/company-manager-loses-rm132900-to-macau-scam/',
#   'category': 'scam'},
#  {'key': 'k1626',
#   'tokenised_content': ['lucrative',
#    'among',
#    'cigarette',
#    'smuggling',
#    'still',
#    'rampant',
#    'country',
#    'fact',
#    'cigarette',
#    'smuggling',
#    'past',
#    'despite',
#    'covid',
#    'pandemic',
#    'regular',
#    'enforcement',
#    'according',
#    'battalion',
#    'general',
#    'force',
#    'commanding',
#    'officer',
#    'said',
#    'seize',
#    'various',
#    'worth',
#    'contraband',
#    'worth',
#    'last',
#    'year',
#    'total',
#    'worth',
#    'march',
#    'year',
#    'told',
#    'said',
#    'used',
#    'different',
#    'tactic',
#    'various',
#    'prevent',
#    'detection',
#    'illicit',
#    'high',
#    'demand',
#    'lucrative',
#    'said',
#    'said',
#    'avoid',
#    'detection',
#    'behind',
#    'legal',
#    'route',
#    'known',
#    'elephant',
#    'trail',
#    'major',
#    'said',
#    'every',
#    'entering',
#    'port',
#    'quite',
#    'difficult',
#    'detect',
#    'contraband',
#    'falsely',
#    'declared',
#    'permitted',
#    'good',
#    'therefore',
#    'said',
#    'security',
#    'entry',
#    'major',
#    'help',
#    'relevant',
#    'detect',
#    'addition',
#    'increasing',
#    'number',
#    'enforcement',
#    'personnel',
#    'curb',
#    'smuggling'],
#   'tokenised_headline': ['lucrative',
#    'among',
#    'cigarette',
#    'smuggling',
#    'still',
#    'rampant'],
#   'author': '',
#   'datetime': '2022-05-03T12:14:27+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/05/lucrative-returns-among-reasons-cigarette-smuggling-still-rampant/',
#   'category': 'money laundering'},
#  {'key': 'k1627',
#   'tokenised_content': ['collaboration',
#    'watch',
#    'royal',
#    'police',
#    'help',
#    'reduce',
#    'crime',
#    'community',
#    'said',
#    'crime',
#    'prevention',
#    'community',
#    'safety',
#    'department',
#    'principal',
#    'assistant',
#    'director',
#    'said',
#    'main',
#    'include',
#    'investigating',
#    'community',
#    'area',
#    'concerned',
#    'anything',
#    'suspicious',
#    'police',
#    'need',
#    'create',
#    'awareness',
#    'need',
#    'identify',
#    'employment',
#    'external',
#    'enter',
#    'housing',
#    'voluntary',
#    'patrol',
#    'scheme',
#    'available',
#    'community',
#    'able',
#    'monitor',
#    'help',
#    'prevent',
#    'criminal',
#    'told',
#    'recently',
#    'said',
#    'team',
#    'able',
#    'conduct',
#    'housing',
#    'serve',
#    'police',
#    'make',
#    'arrest',
#    'said',
#    'also',
#    'said',
#    'police',
#    'especially',
#    'play',
#    'consultative',
#    'role',
#    'community',
#    'besides',
#    'community',
#    'responsibility',
#    'crime',
#    'prevention',
#    'police',
#    'close',
#    'relationship',
#    'need',
#    'police',
#    'give',
#    'guidance',
#    'identify',
#    'added'],
#   'tokenised_headline': ['police', 'collaboration', 'help', 'check', 'crime'],
#   'author': '',
#   'datetime': '2022-05-03T10:50:54+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/05/krt-police-collaboration-can-help-check-crime-rates/',
#   'category': 'others'},
#  {'key': 'k1631',
#   'tokenised_content': ['police',
#    'found',
#    'criminal',
#    'element',
#    'following',
#    'investigation',
#    'audio',
#    'clip',
#    'linked',
#    'police',
#    'chief',
#    'said',
#    'hence',
#    'department',
#    'handed',
#    'case',
#    'foreign',
#    'ministry',
#    'internal',
#    'investigation',
#    'comment',
#    'matter',
#    'press',
#    'conference',
#    'contingent',
#    'police',
#    'headquarters',
#    'today',
#    'recently',
#    'voice',
#    'recording',
#    'sent',
#    'woman',
#    'title',
#    'regarding',
#    'ministry',
#    'gone',
#    'viral',
#    'social',
#    'medium',
#    'meanwhile',
#    'comment',
#    'issue',
#    'said',
#    'police',
#    'calling',
#    'document',
#    'investigation',
#    'paper',
#    'determine',
#    'whether',
#    'wrongdoing',
#    'said',
#    'call',
#    'several',
#    'assist',
#    'investigation',
#    'complainant',
#    'last',
#    'senator',
#    'spreading',
#    'document',
#    'meeting',
#    'attempt',
#    'cause',
#    'friction',
#    'among',
#    'another',
#    'development',
#    'said',
#    'investigation',
#    'theft',
#    'vehicle',
#    'shopping',
#    'mall',
#    'capital',
#    'last',
#    'discovery',
#    'luxury',
#    'various',
#    'several',
#    'value',
#    'million',
#    'following',
#    'said',
#    'nine',
#    'aged',
#    'across',
#    'country',
#    'said',
#    'first',
#    'information',
#    'disposed',
#    'insurance',
#    'information',
#    'group',
#    'identification',
#    'disposed',
#    'stolen',
#    'said'],
#   'tokenised_headline': ['criminal',
#    'element',
#    'found',
#    'audio',
#    'clip',
#    'police'],
#   'author': '',
#   'datetime': '2022-04-27T17:51:50+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/04/no-criminal-element-found-in-wisma-putra-linked-audio-clip-police/',
#   'category': 'robbery or theft'},
#  {'key': 'k1632',
#   'tokenised_content': ['police',
#    'received',
#    'fraudulent',
#    'clothing',
#    'raya',
#    'celebration',
#    'first',
#    'four',
#    'year',
#    'commercial',
#    'crime',
#    'investigation',
#    'department',
#    'director',
#    'said',
#    'department',
#    'fraud',
#    'syndicate',
#    'actively',
#    'sale',
#    'raya',
#    'clothes',
#    'equipment',
#    'social',
#    'medium',
#    'said',
#    'found',
#    'receive',
#    'making',
#    'high',
#    'demand',
#    'clothes',
#    'syndicate',
#    'advertising',
#    'nonexistent',
#    'social',
#    'medium',
#    'people',
#    'advised',
#    'avoid',
#    'making',
#    'dubious',
#    'said',
#    'statement',
#    'today',
#    'said',
#    'public',
#    'contact',
#    'scam',
#    'response',
#    'center',
#    'well',
#    'portal',
#    'check',
#    'bank',
#    'telephone',
#    'possibly',
#    'used',
#    'criminal'],
#   'tokenised_headline': ['police', 'receive', 'fraud', 'nearly'],
#   'author': '',
#   'datetime': '2022-04-26T19:16:35+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/04/police-receive-22-reports-of-aidilfitri-sales-fraud-involving-losses-of-nearly-rm20000/',
#   'category': 'scam'},
#  {'key': 'k1634',
#   'tokenised_content': ['company',
#    'director',
#    'default',
#    'four',
#    'jail',
#    'session',
#    'court',
#    'today',
#    'possessing',
#    'selling',
#    'communication',
#    'equipment',
#    'certified',
#    'commission',
#    'judge',
#    'fine',
#    'marketing',
#    'network',
#    'medium',
#    'director',
#    'guilty',
#    'plea',
#    'read',
#    'mandarin',
#    'proceeding',
#    'hear',
#    'case',
#    'guilty',
#    'court',
#    'also',
#    'ordered',
#    'case',
#    'handed',
#    'investigating',
#    'officer',
#    'forfeiture',
#    'marketing',
#    'network',
#    'possessing',
#    'selling',
#    'wireless',
#    'medium',
#    'certified',
#    'digital',
#    'mall',
#    'june',
#    'framed',
#    'regulation',
#    'technical',
#    'punishable',
#    'regulation',
#    'maximum',
#    'fine',
#    'imprisonment',
#    'upon',
#    'conviction',
#    'prosecution',
#    'officer',
#    'prosecution',
#    'accused',
#    'lawyer'],
#   'tokenised_headline': ['company',
#    'director',
#    'selling',
#    'uncertified',
#    'communication',
#    'equipment'],
#   'author': '',
#   'datetime': '2022-04-26T17:34:36+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/04/company-director-fined-rm10000-each-for-selling-uncertified-communication-equipment/',
#   'category': 'money laundering'},
#  {'key': 'k1636',
#   'tokenised_content': ['civil',
#    'servant',
#    'commission',
#    'last',
#    'suspicion',
#    'soliciting',
#    'bribe',
#    'according',
#    'source',
#    'solicited',
#    'bribe',
#    'gratification',
#    'giving',
#    'several',
#    'sanitation',
#    'work',
#    'polling',
#    'recent',
#    'state',
#    'election',
#    'source',
#    'said',
#    'suspect',
#    'individual',
#    'year',
#    'similar',
#    'individual',
#    'involved',
#    'able',
#    'provide',
#    'suspect',
#    'agreed',
#    'reduced',
#    'amount',
#    'meet',
#    'individual',
#    'last',
#    'receive',
#    'money',
#    'said',
#    'source',
#    'meanwhile',
#    'intelligence',
#    'division',
#    'director',
#    'confirmed',
#    'arrest',
#    'investigation',
#    'section',
#    'suspect',
#    'remand',
#    'four',
#    'today',
#    'bail'],
#   'tokenised_headline': ['civil', 'servant', 'bribe'],
#   'author': '',
#   'datetime': '2022-04-26T16:15:54+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/04/civil-servant-arrested-for-accepting-rm100000-bribe/',
#   'category': 'money laundering'},
#  {'key': 'k1637',
#   'tokenised_content': ['police',
#    'scam',
#    'application',
#    'name',
#    'commercial',
#    'crime',
#    'investigation',
#    'department',
#    'director',
#    'said',
#    'four',
#    'police',
#    'lodged',
#    'syndicate',
#    'process',
#    'lucrative',
#    'wage',
#    'around',
#    'added',
#    'investigation',
#    'found',
#    'interested',
#    'transfer',
#    'money',
#    'company',
#    'syndicate',
#    'bank',
#    'account',
#    'belonging',
#    'individual',
#    'mule',
#    'account',
#    'early',
#    'receive',
#    'profit',
#    'company',
#    'relationship',
#    'investor',
#    'investment',
#    'money',
#    'said',
#    'statement',
#    'today',
#    'said',
#    'company',
#    'never',
#    'made',
#    'offer',
#    'also',
#    'advised',
#    'public',
#    'check',
#    'company',
#    'especially',
#    'request',
#    'money',
#    'private',
#    'individual',
#    'bank',
#    'public',
#    'also',
#    'contact',
#    'commercial',
#    'crime',
#    'investigation',
#    'department',
#    'scam',
#    'response'],
#   'tokenised_headline': ['detect', 'scam', 'name'],
#   'author': '',
#   'datetime': '2022-04-25T21:07:12+08:00',
#   'publisher': 'Selangor Journal',
#   'url': 'https://selangorjournal.my/2022/04/cops-detect-job-scam-using-nexeas-name/',
#   'category': 'scam'},
#  ...]

# %%
spark.stop()

# %%
redis_client.stop_service()
# Out:
# [sudo] password for student:
